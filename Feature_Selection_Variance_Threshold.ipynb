# %% [markdown]
# <a href="https://colab.research.google.com/github/saishrane06/Feature-Selection-Techniques/blob/main/Feature_Selection_Variance_Threshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
df = pd.read_csv('ford.csv')
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
from sklearn import preprocessing
Transmission_temp = preprocessing.LabelEncoder()
Transmission_temp.fit(df["transmission"])
Transmission_temp.classes_
Transmission=Transmission_temp.transform(df["transmission"])


fueltype_temp =  preprocessing.LabelEncoder()
fueltype_temp.fit(df["fuelType"])
fueltype_temp.classes_
fueltype=fueltype_temp.transform(df["fuelType"])

# %%
df.drop(["model","transmission","fuelType"],axis=1,inplace=True)

# %%
Transmission=pd.Series(Transmission)
fueltype=pd.Series(fueltype)

df=pd.concat([df,Transmission,fueltype],axis=1)
df.rename(columns={"0":""})
df.head()
# Out:
#    year  price  mileage  tax   mpg  engineSize  0  1
# 0  2017  12000    15944  150  57.7         1.0  0  4
# 1  2018  14000     9083  150  57.7         1.0  1  4
# 2  2017  13000    12456  150  57.7         1.0  1  4
# 3  2019  17500    10460  145  40.3         1.5  1  4
# 4  2019  16500     1482  145  48.7         1.0  0  4

# %%
df.rename(columns={0:'Transmission',1:'fueltype'},inplace=True)
df.columns
# Out:
# Index(['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize', 'Transmission',
#        'fueltype'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize', 'Transmission',
#        'fueltype'],
#       dtype='object')

# %%
X = df.drop('price',axis=1)
y = df['price']

# %%
X.head()
# Out:
#    year  mileage  tax   mpg  engineSize  Transmission  fueltype
# 0  2017    15944  150  57.7         1.0             0         4
# 1  2018     9083  150  57.7         1.0             1         4
# 2  2017    12456  150  57.7         1.0             1         4
# 3  2019    10460  145  40.3         1.5             1         4
# 4  2019     1482  145  48.7         1.0             0         4

# %%
y.head()
# Out:
# 0    12000
# 1    14000
# 2    13000
# 3    17500
# 4    16500
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((12576, 7), (5390, 7))

# %%
var_threshold = VarianceThreshold(threshold=0)
var_threshold.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_threshold.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True])

# %%
sum(var_threshold.get_support())
# Out:
# 7

# %%
len(X_train.columns[var_threshold.get_support()])
# Out:
# 7

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_threshold.get_support()]]

print(len(constant_columns))
# Out:
# 0

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download junglisher/vehicle-insurance-data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# vehicle-insurance-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip vehicle-insurance-data.zip
# Out:
# Archive:  vehicle-insurance-data.zip
# replace VehicleInsuranceData.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: VehicleInsuranceData.csv

# %%
vi_df = pd.read_csv("VehicleInsuranceData.csv")
vi_df.head()
# Out:
#    Unnamed: 0           clv Response  Coverage Education EmploymentStatus  \
# 0           1   2763.519279       No     Basic  Bachelor         Employed
# 1           2   6979.535903       No  Extended  Bachelor       Unemployed
# 2           3  12887.431650       No   Premium  Bachelor         Employed
# 3           4   7645.861827       No     Basic  Bachelor       Unemployed
# 4           5   2813.692575       No     Basic  Bachelor         Employed
#
#   Gender  Income Location.Code Marital.Status  ...  \
# 0      F   56274      Suburban        Married  ...
# 1      F       0      Suburban         Single  ...
# 2      F   48767      Suburban        Married  ...
# 3      M       0      Suburban        Married  ...
# 4      M   43836         Rural         Single  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                              5                          0
# 1                             42                          0
# ...

# %%
vi_df.columns
# Out:
# Index(['Unnamed: 0', 'clv', 'Response', 'Coverage', 'Education',
#        'EmploymentStatus', 'Gender', 'Income', 'Location.Code',
#        'Marital.Status', 'Monthly.Premium.Auto', 'Months.Since.Last.Claim',
#        'Months.Since.Policy.Inception', 'Number.of.Open.Complaints',
#        'Number.of.Policies', 'Policy.Type', 'Policy', 'Renew.Offer.Type',
#        'Sales.Channel', 'Total.Claim.Amount', 'Vehicle.Class', 'Vehicle.Size'],
#       dtype='object')

# %%
for i in vi_df:
  print(i)
  print("\n")
  print(vi_df[i].value_counts())
  print("\n")
# Out:
# Unnamed: 0
#
#
# 1       1
# 6077    1
# 6091    1
# 6090    1
# 6089    1
#        ..
# 3021    1
# 3020    1
# 3019    1
# 3018    1
# 9134    1
# Name: Unnamed: 0, Length: 8630, dtype: int64
#
#
# clv
#
#
# 9031.214859    6
# 8622.835375    6
# 8609.158215    6
# 5989.773931    6
# 4349.308750    6
#               ..
# 8521.738901    1
# 5493.698779    1
# 3920.511337    1
# 2685.425957    1
# 2611.836866    1
# Name: clv, Length: 7602, dtype: int64
#
#
# Response
#
#
# No     7400
# Yes    1230
# Name: Response, dtype: int64
#
#
# Coverage
#
#
# Basic       5314
# Extended    2563
# Premium      753
# Name: Coverage, dtype: int64
#
#
# Education
#
#
# Bachelor                2592
# College                 2549
# High School or Below    2465
# Master                   700
# Doctor                   324
# Name: Education, dtype: int64
#
#
# EmploymentStatus
#
#
# Employed         5366
# Unemployed       2212
# Medical Leave     407
# Disabled          381
# Retired           264
# ...

# %%
vi_df.drop("Unnamed: 0",axis=1)
# Out:
#                clv Response  Coverage Education EmploymentStatus Gender  \
# 0      2763.519279       No     Basic  Bachelor         Employed      F
# 1      6979.535903       No  Extended  Bachelor       Unemployed      F
# 2     12887.431650       No   Premium  Bachelor         Employed      F
# 3      7645.861827       No     Basic  Bachelor       Unemployed      M
# 4      2813.692575       No     Basic  Bachelor         Employed      M
# ...            ...      ...       ...       ...              ...    ...
# 8625   4100.398533       No   Premium   College         Employed      F
# 8626   3096.511217      Yes  Extended   College         Employed      F
# 8627   8163.890428       No  Extended  Bachelor       Unemployed      M
# 8628   7524.442436       No  Extended   College         Employed      M
# 8629   2611.836866       No  Extended   College       Unemployed      M
#
#       Income Location.Code Marital.Status  Monthly.Premium.Auto  ...  \
# ...

# %%
vi_df.describe()
# Out:
#         Unnamed: 0           clv        Income  Monthly.Premium.Auto  \
# count  8630.000000   8630.000000   8630.000000           8630.000000
# mean   4560.576825   6725.281515  37586.405794             91.677057
# std    2637.448711   3934.876313  30453.838594             32.648209
# min       1.000000   1898.007675      0.000000             61.000000
# 25%    2280.250000   3858.177183      0.000000             68.000000
# 50%    4547.500000   5569.220419  33817.000000             81.000000
# 75%    6852.750000   8456.408530  62250.750000            108.000000
# max    9134.000000  21235.445570  99981.000000            298.000000
#
#        Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# count              8630.000000                    8630.000000
# mean                 15.084473                      48.004287
# std                  10.048979                      27.880693
# min                   0.000000                       0.000000
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
vi_df['Response'] = label_encoder.fit_transform(vi_df['Response'])
vi_df['Coverage'] = label_encoder.fit_transform(vi_df['Coverage'])
vi_df['Education'] = label_encoder.fit_transform(vi_df['Education'])
vi_df['EmploymentStatus'] = label_encoder.fit_transform(vi_df['EmploymentStatus'])
vi_df['Gender'] = label_encoder.fit_transform(vi_df['Gender'])
vi_df['Location.Code'] = label_encoder.fit_transform(vi_df['Location.Code'])
vi_df['Marital.Status'] = label_encoder.fit_transform(vi_df['Marital.Status'])
vi_df['Policy.Type'] = label_encoder.fit_transform(vi_df['Policy.Type'])
vi_df['Policy'] = label_encoder.fit_transform(vi_df['Policy'])
vi_df['Renew.Offer.Type'] = label_encoder.fit_transform(vi_df['Renew.Offer.Type'])
vi_df['Sales.Channel'] = label_encoder.fit_transform(vi_df['Sales.Channel'])
vi_df['Vehicle.Class'] = label_encoder.fit_transform(vi_df['Vehicle.Class'])
vi_df['Vehicle.Size'] = label_encoder.fit_transform(vi_df['Vehicle.Size'])

# %%
vi_df.head()
# Out:
#    Unnamed: 0           clv  Response  Coverage  Education  EmploymentStatus  \
# 0           1   2763.519279         0         0          0                 1
# 1           2   6979.535903         0         1          0                 4
# 2           3  12887.431650         0         2          0                 1
# 3           4   7645.861827         0         0          0                 4
# 4           5   2813.692575         0         0          0                 1
#
#    Gender  Income  Location.Code  Marital.Status  ...  \
# 0       0   56274              1               1  ...
# 1       0       0              1               2  ...
# 2       0   48767              1               1  ...
# 3       1       0              1               1  ...
# 4       1   43836              0               2  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                              5                          0
# ...

# %%
vi_df.dtypes
# Out:
# Unnamed: 0                         int64
# clv                              float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# EmploymentStatus                   int64
# Gender                             int64
# Income                             int64
# Location.Code                      int64
# Marital.Status                     int64
# Monthly.Premium.Auto               int64
# Months.Since.Last.Claim            int64
# Months.Since.Policy.Inception      int64
# Number.of.Open.Complaints          int64
# Number.of.Policies                 int64
# Policy.Type                        int64
# Policy                             int64
# Renew.Offer.Type                   int64
# Sales.Channel                      int64
# Total.Claim.Amount               float64
# Vehicle.Class                      int64
# Vehicle.Size                       int64
# dtype: object

# %%
vi_df = vi_df.drop("Unnamed: 0",axis=1)

# %%
X = vi_df.drop("clv",axis=1)
y = vi_df['clv']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres = VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
len(X_train.columns[var_thres.get_support()])
# Out:
# 20

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 0
