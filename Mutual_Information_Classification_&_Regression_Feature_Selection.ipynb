# %% [markdown]
# <a href="https://colab.research.google.com/github/saishrane06/Feature-Selection-Techniques/blob/main/Mutual_Information_Classification_%26_Regression_Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download josemauricioneuro/lung-cancer-patients-mrna-microarray

# %%
! unzip lung-cancer-patients-mrna-microarray.zip

# %%
import pandas as pd
import numpy as np

# %%
lc_df = pd.read_csv("clean/complete_dataframe.csv")
lc_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (22309) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Unnamed: 0  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0  NCI_U133A_93L  10.937022  6.105887  6.657732  8.543040   4.088473
# 1  NCI_U133A_70L   9.667748  6.203607  7.444259  8.800833   4.460766
# 2  NCI_U133A_87L  10.083438  6.416165  7.145344  8.625512   4.135750
# 3  NCI_U133A_64L  10.394160  6.307711  7.290440  8.761087   4.112526
# 4  NCI_U133A_99L  10.890421  6.307370  6.835464  8.524622   4.200539
#
#     1294_at   1316_at   1320_at  1405_i_at  ...  \
# 0  8.208775  5.248811  5.053609   7.042420  ...
# 1  7.960886  5.133321  4.940906   7.618997  ...
# 2  8.499000  5.134877  4.836854   7.089821  ...
# 3  8.463786  5.476750  4.998902   7.725870  ...
# 4  7.584603  5.352621  4.941038   5.878343  ...
#
#                       SURGICAL_MARGINS              PATHOLOGIC_N_STAGE  \
# 0  ALL MARGINS PATHOLOGICALLY NEGATIVE  N0, ACCORDING TO AJCC CRITERIA
# 1  ALL MARGINS PATHOLOGICALLY NEGATIVE  N1, ACCORDING TO AJCC CRITERIA
# 2  ALL MARGINS PATHOLOGICALLY NEGATIVE  N0, ACCORDING TO AJCC CRITERIA
# 3  ALL MARGINS PATHOLOGICALLY NEGATIVE  N0, ACCORDING TO AJCC CRITERIA
# 4  ALL MARGINS PATHOLOGICALLY NEGATIVE  N0, ACCORDING TO AJCC CRITERIA
#
#                PATHOLOGIC_T_STAGE  MEDIAN_INTENSITY_UNNORMALIZED  \
# 0  T2, ACCORDING TO AJCC CRITERIA                          193.0
# 1  T2, ACCORDING TO AJCC CRITERIA                          192.0
# 2  T1, ACCORDING TO AJCC CRITERIA                          192.0
# 3  T2, ACCORDING TO AJCC CRITERIA                          192.0
# 4  T2, ACCORDING TO AJCC CRITERIA                          193.0
#
#    PCT_ARRAY_OUTLIER  PCT_SINGLE_OUTLIER  WARNING  LABORATORY_BATCH  \
# 0              2.643               0.148      NaN               NaN
# 1              1.450               0.184      NaN               NaN
# 2              1.634               0.142      NaN               NaN
# 3              2.850               0.350      NaN               NaN
# 4              3.666               0.244      NaN               NaN
#
#            Histologic grade  High_risk
# 0  Moderate Differentiation        1.0
# 1     POORLY DIFFERENTIATED        0.0
# 2       WELL DIFFERENTIATED        0.0
# 3     POORLY DIFFERENTIATED        0.0
# 4     POORLY DIFFERENTIATED        0.0
#
# [5 rows x 22313 columns]

# %%
lc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Columns: 22313 entries, Unnamed: 0 to High_risk
# dtypes: float64(22293), int64(3), object(17)
# memory usage: 75.2+ MB

# %%
lc_df["SURGICAL_MARGINS"].dtypes
# Out:
# dtype('O')

# %%
for i in lc_df.columns:
  if lc_df[i].dtypes == 'O':
    print(i)
    print("\n")
    print(lc_df[i].unique())
    print("\n")
# Out:
# Unnamed: 0
#
#
# ['NCI_U133A_93L' 'NCI_U133A_70L' 'NCI_U133A_87L' 'NCI_U133A_64L'
#  'NCI_U133A_99L' 'CL20041119183AA' 'NCI_Lung270_U133A' 'Moff1864H'
#  'NCI_Lung75_U133A' 'NCI_Lung23_U133A' 'Moff0928E' 'NCI_Lung91_U133A'
#  'CL2005060333AA' 'NCI_U133A_23L' 'NCI_U133A_25L' 'NCI_U133A_26L'
#  'NCI_U133A_38L' 'NCI_U133A_68L' 'NCI_U133A_32L' 'NCI_U133A_31L'
#  'NCI_Lung44_U133A' 'NCI_U133A_10L' 'NCI_Lung99_U133A' 'CL20041119184AA'
#  'NCI_Lung247_U133A' 'NCI_Lung203_U133A' 'NCI_Lung19_U133A'
#  'NCI_Lung208_U133A' 'Moff1487F' 'CL2005060334AA' 'NCI_Lung259_U133A'
#  'Moff3730B' 'Moff2603I' 'Moff2333J' 'Moff2690H' 'NCI_Lung14_U133A'
#  'Moff3401F' 'NCI_Lung65_U133A' 'NCI_U133A_46L' 'NCI_U133A_9L' 'Moff3053B'
#  'Moff0978B' 'Moff4112G' 'NCI_U133A_52L' 'Moff0711B' 'Moff1835I'
#  'CL2004111045AA' 'NCI_Lung80_U133A' 'Moff1576F' 'Moff2955B'
#  'NCI_Lung281_U133' 'CL2005060344AA' 'NCI_Lung296_U133' 'NCI_Lung46_U133A'
#  'NCI_U133A_8L' 'NCI_Lung212_U133A' 'NCI_Lung67_U133A' 'NCI_Lung16_U133A'
#  'NCI_Lung85_U133A' 'NCI_Lung20_U133A' 'CL20041110110AA' 'CL2004111041AA'
#  'NCI_Lung207_U133A' 'Moff0291A' 'NCI_Lung272_U133A' 'CL2005060349AA'
#  'CL2005060353AA' 'NCI_Lung96_U133A' 'NCI_U133A_27L' 'NCI_U133A_59L'
#  'NCI_Lung239_U133A' 'NCI_Lung289_U133' 'NCI_Lung93_U133A'
#  'NCI_Lung263_U133A' 'NCI_Lung49_U133A' 'NCI_U133A_41L' 'NCI_U133A_3L'
#  'NCI_Lung61_U133A' 'NCI_U133A_98L' 'CL2004111022AA' 'Moff2310K'
#  'NCI_U133A_2L' 'Moff2072G' 'CL2004111048AA' 'NCI_U133A_100L'
#  'NCI_U133A_55L' 'Moff2886F' 'NCI_Lung298_U133' 'CL20041110103AA'
#  'CL20041110108AA' 'Moff2325E' 'CL20041116126AA' 'NCI_Lung269_U133A'
#  'NCI_Lung77_U133A' 'NCI_Lung53_U133A' 'NCI_Lung201_U133A' 'NCI_U133A_77L'
#  'CL2005060346AA' 'NCI_Lung82_U133A' 'CL2005060340AA' 'NCI_U133A_63L'
#  'NCI_U133A_80L' 'NCI_Lung283_U133' 'NCI_Lung33_U133A' 'NCI_Lung249_U133A'
#  'NCI_Lung294_U133' 'CL20041116136AA' 'NCI_Lung26_U133A' 'CL20041119192AA'
#  'NCI_Lung237_U133A' 'Moff1473F' 'NCI_Lung312_U133' 'NCI_U133A_58L'
#  'NCI_Lung22_U133A' 'Moff2362A' 'NCI_Lung59_U133A' 'NCI_Lung100_U133A'
#  'Moff3298E' 'Moff1300F' 'NCI_Lung69_U133A' 'NCI_Lung18_U133A'
#  'NCI_Lung202_U133A' 'NCI_U133A_40L' 'NCI_Lung246_U133A' 'NCI_U133A_54L'
#  'NCI_Lung209_U133A' 'NCI_Lung314_U133A' 'CL2005060356AA' 'Moff2517G1'
#  'NCI_Lung310_U133' 'NCI_Lung228_U133A' 'CL20041116134AA'
#  'CL20041110109AA' 'CL20041116127AA' 'CL2004111017AA' 'CL2005060337AA'
#  'CL20041110102AA' 'NCI_Lung98_U133A' 'NCI_Lung45_U133A' 'CL2005060350AA'
#  'CL2005060339AA' 'NCI_Lung47_U133A' 'NCI_U133A_20L' 'NCI_U133A_107L'
#  'NCI_U133A_15L' 'NCI_U133A_16L' 'NCI_U133A_13L' 'NCI_Lung215_U133A'
#  'NCI_U133A_34L' 'NCI_Lung15_U133A' 'CL2005060360AA' 'Moff2497D'
#  'Moff3009D' 'NCI_Lung267_U133A' 'CL2005060341AA' 'NCI_U133A_76L'
#  'NCI_U133A_95L' 'Moff1817G1' 'Moff2472B' 'NCI_Lung72_U133A'
#  'NCI_U133A_62L' 'NCI_U133A_81L' 'CL20041119194AA' 'CL2005060345AA'
#  'NCI_Lung79_U133A' 'CL20041110111AA' 'NCI_Lung28_U133A'
#  'NCI_Lung231_U133A' 'NCI_Lung3_U133A' 'NCI_Lung97_U133A' 'NCI_U133A_92L'
#  'NCI_Lung17_U133A' 'NCI_U133A_71L' 'NCI_Lung21_U133A' 'Moff1400H'
#  'CL20041110104AA' 'CL2004110909AA' 'NCI_Lung206_U133A' 'NCI_U133A_86L'
#  'NCI_U133A_65L' 'Moff2658C' 'Moff2629F' 'Moff3510G' 'NCI_U133A_102L'
#  'NCI_U133A_39L' 'NCI_Lung95_U133A' 'CL2005060355AA' 'NCI_U133A_69L'
#  'NCI_U133A_47L' 'Moff1477G' 'NCI_U133A_1L' 'NCI_Lung235_U133A'
#  'CL2004111044AA' 'CL2005060328AA' 'NCI_Lung306_U133' 'NCI_Lung300_U133'
#  'NCI_Lung293_U133' 'NCI_Lung48_U133A' 'NCI_U133A_53L' 'Moff2401B'
#  'CL2004111013AA' 'CL20041119185AA' 'Moff1903E' 'Moff1343G'
#  'NCI_Lung307_U133' 'NCI_U133A_17L' 'CL2005060326AA' 'Moff2199G'
#  'NCI_Lung304_U133' 'NCI_Lung291_U133' 'NCI_Lung305_U133' 'CL2005060338AA'
#  'Moff3274K' 'CL20041119182AA' 'NCI_Lung70_U133A' 'NCI_Lung34_U133A'
#  'NCI_Lung219_U133A' 'NCI_U133A_56L' 'NCI_Lung271_U133A' 'NCI_U133A_42L'
#  'NCI_U133A_29L' 'NCI_Lung86_U133A' 'NCI_Lung311_U133' 'Moff0683H'
#  'NCI_Lung7_U133A' 'NCI_Lung222_U133A' 'NCI_U133A_97L' 'CL2004111010AA'
#  'NCI_Lung299_U133' 'NCI_U133A_106L' 'NCI_Lung280_U133A'
#  'NCI_Lung64_U133A' 'NCI_Lung54_U133A' 'CL20041119187AA'
#  'NCI_Lung62_U133A' 'Moff2352G' 'NCI_Lung40_U133A' 'NCI_Lung32_U133A'
#  'NCI_Lung90_U133A' 'Moff1276H' 'Moff2663F' 'NCI_U133A_7L' 'Moff1940G'
#  'CL20041116112AA' 'CL20041119181AA' 'NCI_U133A_5L' 'CL2004111043AA'
#  'NCI_U133A_18L' 'NCI_U133A_83L' 'Moff3003G' 'NCI_U133A_60L' 'Moff4217B'
#  'NCI_Lung258_U133A' 'NCI_U133A_74L' 'NCI_U133A_94L_Rep' 'CL2005060343AA'
#  'Moff0770K' 'Moff0936G' 'NCI_Lung319_U133A' 'NCI_Lung52_U133A'
#  'NCI_Lung81_U133A' 'NCI_U133A_33L' 'NCI_U133A_35L' 'NCI_U133A_14L'
#  'NCI_Lung74_U133A' 'NCI_Lung288_U133' 'CL20041116114AA'
#  'NCI_Lung25_U133A' 'NCI_U133A_78L' 'NCI_U133A_22L' 'NCI_U133A_21L'
#  'Moff1514K' 'NCI_Lung56_U133A' 'CL2004111038AA' 'NCI_Lung39_U133A'
#  'CL2005060342AA' 'CL2005060336AA' 'NCI_Lung274_U133A' 'NCI_Lung13_U133A'
#  'NCI_U133A_88L' 'CL20041119167AA' 'NCI_Lung8_U133A' 'Moff3191I'
#  'Moff0130D' 'CL2004111040AA' 'NCI_Lung89_U133A' 'NCI_Lung76_U133A'
#  'NCI_Lung204_U133A' 'NCI_U133A_19L' 'NCI_U133A_101L' 'NCI_Lung210_U133A'
#  'Moff2219F' 'NCI_Lung92_U133A' 'NCI_Lung36_U133A' 'CL20041110107AA'
#  'Moff2634G' 'NCI_Lung320_U133A' 'NCI_U133A_67L' 'NCI_U133A_84L'
#  'NCI_Lung268_U133A' 'CL2005060327AA' 'NCI_Lung5_U133A' 'NCI_Lung11_U133A'
#  'NCI_Lung27_U133A' 'Moff0184A' 'NCI_U133A_73L' 'NCI_U133A_90L'
#  'NCI_Lung290_U133' 'NCI_Lung60_U133A' 'NCI_Lung238_U133A'
#  'NCI_Lung66_U133A' 'Moff2550F' 'CL2005060357AA' 'NCI_U133A_49L'
#  'Moff2186B' 'CL2004111018AA' 'NCI_Lung41_U133A' 'NCI_Lung43_U133A'
#  'NCI_Lung220_U133A' 'NCI_Lung84_U133A' 'NCI_U133A_51L' 'CL2004111097AA'
#  'NCI_Lung213_U133A' 'NCI_Lung276_U133A' 'NCI_Lung292_U133' 'Moff0298B'
#  'CL20041119190AA' 'NCI_U133A_45L' 'NCI_U133A_4L' 'Moff2996G'
#  'NCI_Lung227_U133A' 'CL2004111098AA' 'NCI_Lung286_U133' 'NCI_U133A_89L'
#  'NCI_U133A_12L' 'NCI_U133A_11L' 'NCI_U133A_30L' 'NCI_U133A_24L'
#  'NCI_U133A_37L_Rep' 'NCI_Lung224_U133A' 'Moff1888E' 'NCI_Lung218_U133A'
#  'Moff2373H' 'NCI_Lung29_U133A' 'NCI_Lung78_U133A' 'NCI_Lung42_U133A'
#  'CL20041119191AA' 'NCI_U133A_6L' 'NCI_Lung240_U133A' 'NCI_U133A_66L'
#  'NCI_U133A_85L' 'CL2004111002AA' 'NCI_U133A_28L' 'NCI_U133A_72L'
#  'NCI_U133A_91L' 'CL20041116156AA' 'CL2005060352AA' 'NCI_Lung50_U133A'
#  'NCI_Lung309_U133' 'Moff2958D' 'NCI_Lung229_U133A' 'NCI_Lung273_U133A'
#  'Moff1221F' 'NCI_Lung285_U133' 'NCI_Lung236_U133A' 'CL2005060332AA'
#  'Moff1883G' 'NCI_Lung68_U133A' 'NCI_Lung55_U133A' 'NCI_Lung57_U133A'
#  'CL2005060354AA' 'NCI_Lung83_U133A' 'Moff0480I' 'NCI_Lung297_U133'
#  'NCI_Lung214_U133A' 'NCI_U133A_48L' 'NCI_Lung282_U133' 'NCI_Lung35_U133A'
#  'NCI_Lung37_U133A' 'Moff2366C' 'CL2005060348AA' 'NCI_Lung6_U133A'
#  'NCI_U133A_50L' 'NCI_Lung275_U133A' 'NCI_Lung4_U133A' 'Moff2595A'
#  'Moff0142C' 'NCI_U133A_44L' 'NCI_Lung295_U133' 'NCI_Lung318_U133A'
#  'Moff4094F' 'CL2005060358AA' 'NCI_Lung31_U133A' 'Moff4172B'
#  'NCI_Lung205_U133A' 'NCI_U133A_57L' 'NCI_U133A_103L' 'CL2005060329AA'
#  'NCI_Lung278_U133A' 'CL20041119179AA' 'NCI_Lung63_U133A'
#  'NCI_Lung12_U133A' 'NCI_U133A_43L' 'NCI_Lung51_U133A' 'NCI_Lung321_U133A'
#  'Moff2296D' 'Moff0604H' 'NCI_Lung234_U133A' 'NCI_Lung10_U133A'
#  'CL2004111033AA' 'CL2005060351AA' 'Moff0542F' 'CL20041119180AA'
#  'Moff2470G' 'CL20041110100AA' 'CL20041116113AA' 'NCI_U133A_82L'
#  'CL2004111003AA' 'NCI_U133A_61L' 'CL20041119186AA' 'Moff0686G'
#  'NCI_Lung30_U133A' 'NCI_Lung73_U133A' 'Moff0404A' 'NCI_Lung221_U133A'
#  'NCI_U133A_96L' 'NCI_U133A_75L' 'NCI_Lung58_U133A' 'NCI_Lung313_U133'
#  'NCI_Lung1_U133A' 'NCI_Lung38_U133A' 'NCI_Lung230_U133A'
#  'CL20041119175AA' 'CL2004111046AA' 'NCI_U133A_79L' 'NCI_Lung277_U133A'
#  'NCI_Lung71_U133A' 'Moff0170D' 'Moff2463A' 'CL2004111042AA' 'Moff0516E'
#  'Moff1734M']
#
#
# BlindedIDs
#
#
# ['None4TestSets' '252020' '148178' '712593' '940717' '942053' '106215'
#  '824464' '383339' '524193' '285899' '474137' '707539' '720074' '747041'
#  '568752' '153791' '193820' '391232' '185234' '125786' '455846' '489693'
#  '888397' '448123' '943565' '675746' '226787' '559504' '678515' '687055'
#  '569800' '466286' '404793' '595143' '951138' '233644' '644307' '913626'
#  '728260' '456606' '168962' '943098' '144058' '452459' '232490' '106831'
#  '323875' '316985' '836317' '123673' '201791' '510932' '850333' '414965'
#  '768123' '613415' '222148' '632516' '567176' '800868' '177138' '663986'
#  '662699' '265738' '599309' '291570' '932215' '512292' '624292' '216432'
#  '701581' '627727' '150128' '999364' '941480' '278098' '856475' '684308'
#  '476148' '730255' '949065' '442070' '398109' '110567' '720794' '130882'
#  '112527' '714441' '925629' '376123' '170897' '202710' '496607' '183391'
#  '665227' '618295' '542450' '522090' '525810' '352567' '189573' '816895'
#  '950812' '333004' '903414' '618265' '769668' '871677' '555993' '537180'
#  '517541' '144587' '759490' '913728' '659306' '441465' '411207' '457685'
#  '814773' '173905' '683907' '579761' '826771' '704322' '145764' '956943'
#  '655329' '793551' '255153' '445613' '139107' '474142' '763623' '463273'
#  '424579' '810832' '223314' '366281' '430943' '733074' '391371' '238604'
#  '209144' '933667' '936089' '186573' '702722' '251789' '914179' '907052'
#  '271063' '792784' '450566' '403432' '980608' '901304' '842714' '824309'
#  '524145' '458398' '341749' '812142' '859039' '697490' '458369' '596271'
#  '334341' '165242' '496854' '944357' '432758' '952867' '950017' '659223'
#  '229977' '799354' '337738' '733168' '419309' '602007' '638118' '414808'
#  '693336' '360794' '263320' '772404' '281485' '631005' '721388' '718672'
#  '509008' '845868' '704524' '897384' '493037' '450320' '747262' '518640'
#  '978734' '284987' '510311' '798369' '878703' '819465' '495197' '425795'
#  '517608' '600210' '626325' '211233' '448068' '885163' '907554' '670954'
#  '161979' '163436' '418227' '221190' '744956' '402191' '440283' '696540'
#  '993179' '661131' '569229' '996308' '651553' '306267' '321219' '443769'
#  '182934' '370811' '192850' '172712' '953746' '781068' '608583' '584736'
#  '360466' '159395' '247671' '731954' '942581' '323092' '922659' '829361'
#  '880814' '888981' '668131' '977057' '265064' '826326' '701182' '249311'
#  '161179' '894965']
#
#
# DC_STUDY_ID
#
#
# ['B-NCI_U133A_93L.CHP' 'B-NCI_U133A_70L.CHP' 'B-NCI_U133A_87L.CHP'
#  'B-NCI_U133A_64L.CHP' 'B-NCI_U133A_99L.CHP' 'D257' 'A270' 'C1864H' 'A75'
#  'A23' 'C0928E1' 'A91' 'D111' 'B-NCI_U133A_23L.CHP' 'B-NCI_U133A_25L.CHP'
#  'B-NCI_U133A_26L.CHP' 'B-NCI_U133A_38L.CHP' 'B-NCI_U133A_68L.CHP'
#  'B-NCI_U133A_32L.CHP' 'B-NCI_U133A_31L.CHP' 'A44' 'B-NCI_U133A_10L.CHP'
#  'A99' 'D259' 'A247' 'A203' 'A19' 'A208' 'C1487F' 'D114' 'A259' 'C3730B'
#  'C2603I' 'C2333J' 'C2690H' 'A14' 'C3401F' 'A65' 'B-NCI_U133A_46L.CHP'
#  'B-NCI_U133A_9L.CHP' 'C3053B' 'C978B' 'C4112G' 'B-NCI_U133A_52L.CHP'
#  'C0711B' 'C1835I1' 'D099' 'A80' 'C1576F' 'C2955B' 'A281' 'D129' 'A296'
#  'A46' 'B-NCI_U133A_8L.CHP' 'A212' 'A67' 'A16' 'A85' 'A20' 'D182' 'D095'
#  'A207' 'C291A' 'A272' 'D135' 'D143' 'A96' 'B-NCI_U133A_27L.CHP'
#  'B-NCI_U133A_59L.CHP' 'A239' 'A289' 'A93' 'A263' 'A49'
#  'B-NCI_U133A_41L.CHP' 'B-NCI_U133A_3L.CHP' 'A61' 'B-NCI_U133A_98L.CHP'
#  'D050' 'C2310K' 'B-NCI_U133A_2L.CHP' 'C2072G' 'D102'
#  'B-NCI_U133A_100L.CH' 'B-NCI_U133A_55L.CHP' 'C2886F' 'A298' 'D172' 'D180'
#  'C2325E' 'D200' 'A269' 'A77' 'A53' 'A201' 'B-NCI_U133A_77L.CHP' 'D131'
#  'A82' 'D123' 'B-NCI_U133A_63L.CHP' 'B-NCI_U133A_80L.CHP' 'A283' 'A33'
#  'A249' 'A294' 'D211' 'A26' 'D270' 'A237' 'C1473F' 'A312'
#  'B-NCI_U133A_58L.CHP' 'A22' 'C2362A' 'A59' 'A100' 'C3298E' 'C1300F' 'A69'
#  'A18' 'A202' 'B-NCI_U133A_40L.CHP' 'A246' 'B-NCI_U133A_54L.CHP' 'A209'
#  'A314' 'D149' 'C2517G1' 'A310' 'A228' 'D209' 'D181' 'D201' 'D036' 'D118'
#  'D171' 'A98' 'A45' 'D136' 'D121' 'A47' 'B-NCI_U133A_20L.CHP'
#  'B-NCI_U133A_107L.CH' 'B-NCI_U133A_15L.CHP' 'B-NCI_U133A_16L.CHP'
#  'B-NCI_U133A_13L.CHP' 'A215' 'B-NCI_U133A_34L.CHP' 'A15' 'D164' 'C2497D'
#  'C3009D' 'A267' 'D124' 'B-NCI_U133A_76L.CHP' 'B-NCI_U133A_95L.CHP'
#  'C1817G1' 'C2472B' 'A72' 'B-NCI_U133A_62L.CHP' 'B-NCI_U133A_81L.CHP'
#  'D272' 'D130' 'A79' 'D183' 'A28' 'A231' 'A3' 'A97' 'B-NCI_U133A_92L.CHP'
#  'A17' 'B-NCI_U133A_71L.CHP' 'A21' 'C1400H' 'D173' 'D024B' 'A206'
#  'B-NCI_U133A_86L.CHP' 'B-NCI_U133A_65L.CHP' 'C2658C' 'C2629F' 'C3510G'
#  'B-NCI_U133A_102L.CH' 'B-NCI_U133A_39L.CHP' 'A95' 'D148'
#  'B-NCI_U133A_69L.CHP' 'B-NCI_U133A_47L.CHP' 'C1477G' 'B-NCI_U133A_1L.CHP'
#  'A235' 'D098' 'D106' 'A306' 'A300' 'A293' 'A48' 'B-NCI_U133A_53L.CHP'
#  'C2401B' 'D030' 'D260' 'C1903E1' 'C1343G' 'A307' 'B-NCI_U133A_17L.CHP'
#  'D104' 'C2199G' 'A304' 'A291' 'A305' 'D120' 'C3274K' 'D255' 'A70' 'A34'
#  'A219' 'B-NCI_U133A_56L.CHP' 'A271' 'B-NCI_U133A_42L.CHP'
#  'B-NCI_U133A_29L.CHP' 'A86' 'A311' 'C0683H' 'A7' 'A222'
#  'B-NCI_U133A_97L.CHP' 'D026' 'A299' 'B-NCI_U133A_106L.CH' 'A280' 'A64'
#  'A54' 'D262' 'A62' 'C2352G' 'A40' 'A32' 'A90' 'C1276H' 'C2663F'
#  'B-NCI_U133A_7L.CHP' 'C1940G' 'D184' 'D254' 'B-NCI_U133A_5L.CHP' 'D097'
#  'B-NCI_U133A_18L.CHP' 'B-NCI_U133A_83L.CHP' 'C3003G'
#  'B-NCI_U133A_60L.CHP' 'C4217B' 'A258' 'B-NCI_U133A_74L.CHP'
#  'B-NCI_U133A_94L_Rep' 'D128' 'C0770K' 'C0936G1' 'A319' 'A52' 'A81'
#  'B-NCI_U133A_33L.CHP' 'B-NCI_U133A_35L.CHP' 'B-NCI_U133A_14L.CHP' 'A74'
#  'A288' 'D186' 'A25' 'B-NCI_U133A_78L.CHP' 'B-NCI_U133A_22L.CHP'
#  'B-NCI_U133A_21L.CHP' 'C1514K' 'A56' 'D091' 'A39' 'D126' 'D117' 'A274'
#  'A13' 'B-NCI_U133A_88L.CHP' 'D250' 'A8' 'C3191I' 'C0130D' 'D094' 'A89'
#  'A76' 'A204' 'B-NCI_U133A_19L.CHP' 'B-NCI_U133A_101L.CH' 'A210' 'C2219F'
#  'A92' 'A36' 'D179' 'C2634G' 'A320' 'B-NCI_U133A_67L.CHP'
#  'B-NCI_U133A_84L.CHP' 'A268' 'D105' 'A5' 'A11' 'A27' 'C0184A'
#  'B-NCI_U133A_73L.CHP' 'B-NCI_U133A_90L.CHP' 'A290' 'A60' 'A238' 'A66'
#  'C2550F' 'D151' 'B-NCI_U133A_49L.CHP' 'C2186B' 'D037' 'A41' 'A43' 'A220'
#  'A84' 'B-NCI_U133A_51L.CHP' 'D165' 'A213' 'A276' 'A292' 'C298B' 'D266'
#  'B-NCI_U133A_45L.CHP' 'B-NCI_U133A_4L.CHP' 'C2996G' 'A227' 'D166' 'A286'
#  'B-NCI_U133A_89L.CHP' 'B-NCI_U133A_12L.CHP' 'B-NCI_U133A_11L.CHP'
#  'B-NCI_U133A_30L.CHP' 'B-NCI_U133A_24L.CHP' 'B-NCI_U133A_37L_Rep' 'A224'
#  'C1888E1' 'A218' 'C2373H' 'A29' 'A78' 'A42' 'D269' 'B-NCI_U133A_6L.CHP'
#  'A240' 'B-NCI_U133A_66L.CHP' 'B-NCI_U133A_85L.CHP' 'D008'
#  'B-NCI_U133A_28L.CHP' 'B-NCI_U133A_72L.CHP' 'B-NCI_U133A_91L.CHP' 'D236'
#  'D141' 'A50' 'A309' 'C2958D' 'A229' 'A273' 'C1221F' 'A285' 'A236' 'D110'
#  'C1883G' 'A68' 'A55' 'A57' 'D147' 'A83' 'C0480I' 'A297' 'A214'
#  'B-NCI_U133A_48L.CHP' 'A282' 'A35' 'A37' 'C2366C' 'D134' 'A6'
#  'B-NCI_U133A_50L.CHP' 'A275' 'A4' 'C2595A' 'C142C' 'B-NCI_U133A_44L.CHP'
#  'A295' 'A318' 'C4094F' 'D153' 'A31' 'C4172B' 'A205' 'B-NCI_U133A_57L.CHP'
#  'B-NCI_U133A_103L.CH' 'D107' 'A278' 'D252' 'A63' 'A12'
#  'B-NCI_U133A_43L.CHP' 'A51' 'A321' 'C2296D' 'C0604H' 'A234' 'A10' 'D070B'
#  'D138' 'C542F' 'D253' 'C2470G' 'D169' 'D185' 'B-NCI_U133A_82L.CHP'
#  'D009B' 'B-NCI_U133A_61L.CHP' 'D261' 'C0686G' 'A30' 'A73' 'C0404A' 'A221'
#  'B-NCI_U133A_96L.CHP' 'B-NCI_U133A_75L.CHP' 'A58' 'A313' 'A1' 'A38'
#  'A230' 'D060B' 'D100' 'B-NCI_U133A_79L.CHP' 'A277' 'A71' 'C170D' 'C2463A'
#  'D096' 'C0516E' 'C1734M']
#
#
# SITE
#
#
# ['MSKCC' 'DFCI' 'MI' 'HLM']
#
#
# TESTTYPE
#
#
# ['Test 1' 'Test 2' 'Train']
#
#
# GENDER
#
#
# ['Female' 'Male']
#
#
# RACE
#
#
# ['White(01)' 'Not Reported(98)' 'Unknown(99)' 'Asian(05)'
#  'Black or African American(03)'
#  'Native Hawaiian or Other Pacific Islander(04)']
#
#
# ADJUVANT_CHEMO
#
#
# ['No' 'Yes' 'Unknown']
#
#
# ADJUVANT_RT
#
#
# ['No' 'Yes' 'Unknown']
#
#
# VITAL_STATUS
#
#
# ['Alive' 'Dead']
#
#
# FIRST_PROGRESSION_OR_RELAPSE
#
#
# ['No' 'Yes' nan 'Unknown']
#
#
# SMOKING_HISTORY
#
#
# ['Never smoked' 'Currently smoking' 'Smoked in the past' 'Unknown' nan]
#
#
# SURGICAL_MARGINS
#
#
# ['ALL MARGINS PATHOLOGICALLY NEGATIVE' nan
#  'MICROSCOPICALLY POSITIVE MARGINS OR MICROSCOPIC RESIDUAL DISEASE']
#
#
# PATHOLOGIC_N_STAGE
#
#
# ['N0, ACCORDING TO AJCC CRITERIA' 'N1, ACCORDING TO AJCC CRITERIA'
#  'N2, ACCORDING TO AJCC CRITERIA' nan 'NX, ACCORDING TO AJCC CRITERIA']
#
#
# PATHOLOGIC_T_STAGE
#
#
# ['T2, ACCORDING TO AJCC CRITERIA' 'T1, ACCORDING TO AJCC CRITERIA'
#  'T3, ACCORDING TO AJCC CRITERIA' nan 'T4, ACCORDING TO AJCC CRITERIA']
#
#
# WARNING
#
#
# [nan '*']
#
#
# Histologic grade
#
#
# ['Moderate Differentiation' 'POORLY DIFFERENTIATED' 'WELL DIFFERENTIATED'
#  nan]

# %%
lc_df.set_index("Unnamed: 0")
# Out:
#                 1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at  \
# Unnamed: 0
# NCI_U133A_93L   10.937022  6.105887  6.657732  8.543040   4.088473  8.208775
# NCI_U133A_70L    9.667748  6.203607  7.444259  8.800833   4.460766  7.960886
# NCI_U133A_87L   10.083438  6.416165  7.145344  8.625512   4.135750  8.499000
# NCI_U133A_64L   10.394160  6.307711  7.290440  8.761087   4.112526  8.463786
# NCI_U133A_99L   10.890421  6.307370  6.835464  8.524622   4.200539  7.584603
# ...                   ...       ...       ...       ...        ...       ...
# Moff0170D       10.215343  7.099037  6.927329  8.670335   4.050666  7.398367
# Moff2463A       10.002271  7.142471  6.626329  8.450170   4.064670  7.294477
# CL2004111042AA   9.725443  6.540978  7.327266  9.117646   4.106653  8.158892
# Moff0516E       10.607970  6.442632  7.138329  8.592457   4.149856  8.744266
# Moff1734M       10.692133  7.476039  7.447917  8.496363   4.215873  7.800408
#
#                  1316_at   1320_at  1405_i_at   1431_at  ...  \
# Unnamed: 0                                               ...
# NCI_U133A_93L   5.248811  5.053609   7.042420  4.113564  ...
# NCI_U133A_70L   5.133321  4.940906   7.618997  4.114407  ...
# NCI_U133A_87L   5.134877  4.836854   7.089821  4.171350  ...
# NCI_U133A_64L   5.476750  4.998902   7.725870  4.183584  ...
# NCI_U133A_99L   5.352621  4.941038   5.878343  4.005468  ...
# ...                  ...       ...        ...       ...  ...
# Moff0170D       5.102296  5.042209   6.615265  4.201900  ...
# Moff2463A       5.038166  5.254621   5.373954  4.009913  ...
# CL2004111042AA  5.473464  5.149387   7.677970  4.376579  ...
# Moff0516E       5.145499  4.930338   7.208512  4.318298  ...
# Moff1734M       5.101417  4.868961   7.363595  4.094900  ...
#
#                                    SURGICAL_MARGINS  \
# Unnamed: 0
# NCI_U133A_93L   ALL MARGINS PATHOLOGICALLY NEGATIVE
# NCI_U133A_70L   ALL MARGINS PATHOLOGICALLY NEGATIVE
# NCI_U133A_87L   ALL MARGINS PATHOLOGICALLY NEGATIVE
# NCI_U133A_64L   ALL MARGINS PATHOLOGICALLY NEGATIVE
# NCI_U133A_99L   ALL MARGINS PATHOLOGICALLY NEGATIVE
# ...                                             ...
# Moff0170D       ALL MARGINS PATHOLOGICALLY NEGATIVE
# Moff2463A       ALL MARGINS PATHOLOGICALLY NEGATIVE
# CL2004111042AA  ALL MARGINS PATHOLOGICALLY NEGATIVE
# Moff0516E       ALL MARGINS PATHOLOGICALLY NEGATIVE
# Moff1734M       ALL MARGINS PATHOLOGICALLY NEGATIVE
#
#                             PATHOLOGIC_N_STAGE  \
# Unnamed: 0
# NCI_U133A_93L   N0, ACCORDING TO AJCC CRITERIA
# NCI_U133A_70L   N1, ACCORDING TO AJCC CRITERIA
# NCI_U133A_87L   N0, ACCORDING TO AJCC CRITERIA
# NCI_U133A_64L   N0, ACCORDING TO AJCC CRITERIA
# NCI_U133A_99L   N0, ACCORDING TO AJCC CRITERIA
# ...                                        ...
# Moff0170D       N2, ACCORDING TO AJCC CRITERIA
# Moff2463A       N0, ACCORDING TO AJCC CRITERIA
# CL2004111042AA  N0, ACCORDING TO AJCC CRITERIA
# Moff0516E       N2, ACCORDING TO AJCC CRITERIA
# Moff1734M       N1, ACCORDING TO AJCC CRITERIA
#
#                             PATHOLOGIC_T_STAGE  MEDIAN_INTENSITY_UNNORMALIZED  \
# Unnamed: 0
# NCI_U133A_93L   T2, ACCORDING TO AJCC CRITERIA                          193.0
# NCI_U133A_70L   T2, ACCORDING TO AJCC CRITERIA                          192.0
# NCI_U133A_87L   T1, ACCORDING TO AJCC CRITERIA                          192.0
# NCI_U133A_64L   T2, ACCORDING TO AJCC CRITERIA                          192.0
# NCI_U133A_99L   T2, ACCORDING TO AJCC CRITERIA                          193.0
# ...                                        ...                            ...
# Moff0170D       T1, ACCORDING TO AJCC CRITERIA                          192.0
# Moff2463A       T2, ACCORDING TO AJCC CRITERIA                          192.0
# CL2004111042AA  T2, ACCORDING TO AJCC CRITERIA                          192.0
# Moff0516E       T2, ACCORDING TO AJCC CRITERIA                          192.0
# Moff1734M       T2, ACCORDING TO AJCC CRITERIA                          193.0
#
#                 PCT_ARRAY_OUTLIER  PCT_SINGLE_OUTLIER  WARNING  \
# Unnamed: 0
# NCI_U133A_93L               2.643               0.148      NaN
# NCI_U133A_70L               1.450               0.184      NaN
# NCI_U133A_87L               1.634               0.142      NaN
# NCI_U133A_64L               2.850               0.350      NaN
# NCI_U133A_99L               3.666               0.244      NaN
# ...                           ...                 ...      ...
# Moff0170D                   3.325               0.213      NaN
# Moff2463A                   4.519               0.155      NaN
# CL2004111042AA              6.121               0.806        *
# Moff0516E                   3.303               0.217      NaN
# Moff1734M                   1.481               0.158      NaN
#
#                 LABORATORY_BATCH          Histologic grade  High_risk
# Unnamed: 0
# NCI_U133A_93L                NaN  Moderate Differentiation        1.0
# NCI_U133A_70L                NaN     POORLY DIFFERENTIATED        0.0
# NCI_U133A_87L                NaN       WELL DIFFERENTIATED        0.0
# NCI_U133A_64L                NaN     POORLY DIFFERENTIATED        0.0
# NCI_U133A_99L                NaN     POORLY DIFFERENTIATED        0.0
# ...                          ...                       ...        ...
# Moff0170D                    9.0     POORLY DIFFERENTIATED        1.0
# Moff2463A                    7.0  Moderate Differentiation        0.0
# CL2004111042AA               2.0     POORLY DIFFERENTIATED        0.0
# Moff0516E                    8.0  Moderate Differentiation        1.0
# Moff1734M                    7.0  Moderate Differentiation        0.0
#
# [442 rows x 22312 columns]

# %%
lc_df.isna().any()
# Out:
# Unnamed: 0            False
# 1007_s_at             False
# 1053_at               False
# 117_at                False
# 121_at                False
#                       ...
# PCT_SINGLE_OUTLIER    False
# WARNING                True
# LABORATORY_BATCH       True
# Histologic grade       True
# High_risk             False
# Length: 22313, dtype: bool

# %%
## To find the count of null values
for i in lc_df.columns:
  if lc_df[i].isna().any():
    print(i)
    print(lc_df[i].isna().sum())
# Out:
# FIRST_PROGRESSION_OR_RELAPSE
# 70
# MONTHS_TO_FIRST_PROGRESSION
# 264
# MTHS_TO_LAST_CLINICAL_ASSESSMENT
# 10
# SMOKING_HISTORY
# 2
# SURGICAL_MARGINS
# 2
# PATHOLOGIC_N_STAGE
# 2
# PATHOLOGIC_T_STAGE
# 2
# WARNING
# 410
# LABORATORY_BATCH
# 104
# Histologic grade
# 7

# %%
lc_df.shape
# Out:
# (442, 22313)

# %%
## Since more than fifty percent of the data are nan values we will delete/drop MONTHS_TO_FIRST_PROGRESSION column
lc_df = lc_df.drop("MONTHS_TO_FIRST_PROGRESSION",axis=1)

# %%
lc_df = lc_df[lc_df['MTHS_TO_LAST_CLINICAL_ASSESSMENT'].notna()]
lc_df = lc_df[lc_df['SURGICAL_MARGINS'].notna()]
lc_df = lc_df[lc_df['PATHOLOGIC_N_STAGE'].notna()]
lc_df = lc_df[lc_df['PATHOLOGIC_T_STAGE'].notna()]
lc_df = lc_df[lc_df['Histologic grade'].notna()]

# %%
## beacuse this column dtype is object we will fill nan values after labelencoding
lc_df['FIRST_PROGRESSION_OR_RELAPSE'].unique()
# Out:
# array(['No', 'Yes', nan, 'Unknown'], dtype=object)

# %%
lc_df['LABORATORY_BATCH'] = lc_df['LABORATORY_BATCH'].fillna(lc_df['LABORATORY_BATCH'].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn import preprocessing
label_encoding = preprocessing.LabelEncoder()
lc_df['BlindedIDs'] = label_encoding.fit_transform(lc_df['BlindedIDs'])
lc_df['DC_STUDY_ID'] = label_encoding.fit_transform(lc_df['DC_STUDY_ID'])
lc_df['SITE'] = label_encoding.fit_transform(lc_df['SITE'])
lc_df['TESTTYPE'] = label_encoding.fit_transform(lc_df['TESTTYPE'])
lc_df['GENDER'] = label_encoding.fit_transform(lc_df['GENDER'])
lc_df['RACE'] = label_encoding.fit_transform(lc_df['RACE'])
lc_df['ADJUVANT_CHEMO'] = label_encoding.fit_transform(lc_df['ADJUVANT_CHEMO'])
lc_df['ADJUVANT_RT'] = label_encoding.fit_transform(lc_df['ADJUVANT_RT'])
lc_df['VITAL_STATUS'] = label_encoding.fit_transform(lc_df['VITAL_STATUS'])
lc_df['FIRST_PROGRESSION_OR_RELAPSE'] = label_encoding.fit_transform(lc_df['FIRST_PROGRESSION_OR_RELAPSE'])
lc_df['SMOKING_HISTORY'] = label_encoding.fit_transform(lc_df['SMOKING_HISTORY'])
lc_df['SURGICAL_MARGINS'] = label_encoding.fit_transform(lc_df['SURGICAL_MARGINS'])
lc_df['PATHOLOGIC_N_STAGE'] = label_encoding.fit_transform(lc_df['PATHOLOGIC_N_STAGE'])
lc_df['PATHOLOGIC_T_STAGE'] = label_encoding.fit_transform(lc_df['PATHOLOGIC_T_STAGE'])
lc_df['WARNING'] = label_encoding.fit_transform(lc_df['WARNING'])
lc_df['Histologic grade'] = label_encoding.fit_transform(lc_df['Histologic grade'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
lc_df['FIRST_PROGRESSION_OR_RELAPSE'] = lc_df['FIRST_PROGRESSION_OR_RELAPSE'].fillna(lc_df['FIRST_PROGRESSION_OR_RELAPSE'].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lc_df = lc_df.drop("Unnamed: 0",axis=1)

# %%
lc_df.head()
# Out:
#    1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0  10.937022  6.105887  6.657732  8.543040   4.088473  8.208775  5.248811
# 1   9.667748  6.203607  7.444259  8.800833   4.460766  7.960886  5.133321
# 2  10.083438  6.416165  7.145344  8.625512   4.135750  8.499000  5.134877
# 3  10.394160  6.307711  7.290440  8.761087   4.112526  8.463786  5.476750
# 4  10.890421  6.307370  6.835464  8.524622   4.200539  7.584603  5.352621
#
#     1320_at  1405_i_at   1431_at  ...  SURGICAL_MARGINS  PATHOLOGIC_N_STAGE  \
# 0  5.053609   7.042420  4.113564  ...                 0                   0
# 1  4.940906   7.618997  4.114407  ...                 0                   1
# 2  4.836854   7.089821  4.171350  ...                 0                   0
# 3  4.998902   7.725870  4.183584  ...                 0                   0
# 4  4.941038   5.878343  4.005468  ...                 0                   0
#
#    PATHOLOGIC_T_STAGE  MEDIAN_INTENSITY_UNNORMALIZED  PCT_ARRAY_OUTLIER  \
# 0                   1                          193.0              2.643
# 1                   1                          192.0              1.450
# 2                   0                          192.0              1.634
# 3                   1                          192.0              2.850
# 4                   1                          193.0              3.666
#
#    PCT_SINGLE_OUTLIER  WARNING  LABORATORY_BATCH  Histologic grade  High_risk
# 0               0.148        1         13.009231                 0        1.0
# 1               0.184        1         13.009231                 1        0.0
# 2               0.142        1         13.009231                 2        0.0
# 3               0.350        1         13.009231                 1        0.0
# 4               0.244        1         13.009231                 1        0.0
#
# [5 rows x 22311 columns]

# %%
X = lc_df.drop("High_risk",axis=1)
y = lc_df['High_risk']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((297, 22310), (128, 22310))

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([0.        , 0.        , 0.        , ..., 0.00496657, 0.        ,
#        0.00519499])

# %%
pd.options.display.max_rows = None
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns.tolist()
mutual_info.sort_values(ascending=False)
# Out:
# MONTHS_TO_LAST_CONTACT_OR_DEATH     0.667599
# target                              0.667599
# MTHS_TO_LAST_CLINICAL_ASSESSMENT    0.557121
# VITAL_STATUS                        0.173999
# 202536_at                           0.120727
# 221992_at                           0.116368
# 212227_x_at                         0.115807
# 212316_at                           0.115773
# 203306_s_at                         0.115685
# 219480_at                           0.112823
# 219694_at                           0.112605
# 213640_s_at                         0.111256
# 36742_at                            0.110137
# 220505_at                           0.108756
# 221486_at                           0.108337
# 221658_s_at                         0.103854
# 212013_at                           0.102820
# 207787_at                           0.101367
# 207864_at                           0.100420
# 218597_s_at                         0.099980
# 211058_x_at                         0.099902
# 220691_at                           0.098365
# 64942_at                            0.097663
# 210568_s_at                         0.097241
# 220677_s_at                         0.097104
# 212494_at                           0.094799
# 207152_at                           0.093111
# 206791_s_at                         0.092277
# 203469_s_at                         0.092089
# 48580_at                            0.090506
# 220204_s_at                         0.090224
# 216736_at                           0.090079
# 203514_at                           0.089986
# 53071_s_at                          0.089333
# 59644_at                            0.089205
# 204919_at                           0.089004
# 207245_at                           0.088884
# 210255_at                           0.088828
# 213226_at                           0.088812
# 213190_at                           0.088740
# 204479_at                           0.088655
# 213460_x_at                         0.087723
# 212268_at                           0.087429
# 218165_at                           0.087364
# 218795_at                           0.087239
# 564_at                              0.087188
# 218781_at                           0.087133
# 218992_at                           0.087018
# 213994_s_at                         0.086845
# 210089_s_at                         0.086605
# 216814_at                           0.086439
# 207853_s_at                         0.086291
# 206300_s_at                         0.086153
# 216164_at                           0.085804
# 219900_s_at                         0.085492
# 216544_at                           0.085368
# 201274_at                           0.085187
# 206097_at                           0.085147
# 214663_at                           0.085145
# 212240_s_at                         0.085035
# 220325_at                           0.084840
# 204755_x_at                         0.084354
# 202910_s_at                         0.084333
# 213536_s_at                         0.084236
# 212554_at                           0.084108
# 214693_x_at                         0.084011
# 213885_at                           0.083560
# 218649_x_at                         0.083436
# 44783_s_at                          0.083229
# 215978_x_at                         0.083072
# 207713_s_at                         0.082842
# 206538_at                           0.082804
# 202851_at                           0.082756
# 208787_at                           0.082716
# 221268_s_at                         0.082473
# 210705_s_at                         0.082102
# 221331_x_at                         0.081975
# 220329_s_at                         0.081953
# 205987_at                           0.081712
# 203095_at                           0.081535
# 216366_x_at                         0.081310
# 218065_s_at                         0.081303
# 215280_s_at                         0.081296
# 206240_s_at                         0.081269
# 205268_s_at                         0.080913
# 219016_at                           0.080853
# 218086_at                           0.080823
# 205216_s_at                         0.080635
# 203508_at                           0.080130
# 201165_s_at                         0.080073
# 211068_x_at                         0.079371
# 214390_s_at                         0.079268
# 200647_x_at                         0.079210
# 219348_at                           0.079190
# 217250_s_at                         0.079179
# 216772_at                           0.079004
# 209265_s_at                         0.078745
# 207131_x_at                         0.078720
# 205754_at                           0.078710
# 209460_at                           0.078681
# 204764_at                           0.078656
# 212174_at                           0.078540
# 222182_s_at                         0.078407
# 203559_s_at                         0.078330
# 208273_at                           0.078329
# 202779_s_at                         0.078226
# 214239_x_at                         0.078142
# 217898_at                           0.078109
# 215640_at                           0.077902
# 222263_at                           0.077894
# 215185_at                           0.077874
# 209773_s_at                         0.077782
# 221355_at                           0.077701
# 207235_s_at                         0.077641
# 220133_at                           0.077546
# 209785_s_at                         0.077448
# 211378_x_at                         0.077392
# 218716_x_at                         0.077378
# 205389_s_at                         0.077362
# 207001_x_at                         0.077313
# 211039_at                           0.077275
# 201395_at                           0.077226
# 215444_s_at                         0.077119
# 207888_at                           0.077091
# 209378_s_at                         0.077042
# 203197_s_at                         0.077011
# 216194_s_at                         0.076774
# 217271_at                           0.076525
# 210964_s_at                         0.076483
# 222083_at                           0.076482
# 213311_s_at                         0.076446
# 205044_at                           0.076364
# 211433_x_at                         0.076300
# 201567_s_at                         0.076259
# 218547_at                           0.076243
# 216926_s_at                         0.076113
# 205431_s_at                         0.076027
# 220324_at                           0.075608
# 208775_at                           0.075502
# 220999_s_at                         0.075447
# 219936_s_at                         0.075418
# 215772_x_at                         0.075407
# 201834_at                           0.075402
# 217043_s_at                         0.075398
# 222069_s_at                         0.075374
# 204056_s_at                         0.075296
# 202945_at                           0.075183
# 209819_at                           0.075158
# 204855_at                           0.075127
# 220388_at                           0.074984
# 202041_s_at                         0.074835
# 207866_at                           0.074724
# 215016_x_at                         0.074526
# 212483_at                           0.074147
# 216587_s_at                         0.074086
# 214738_s_at                         0.074011
# 212305_s_at                         0.073998
# 215756_at                           0.073828
# 214146_s_at                         0.073820
# 203060_s_at                         0.073688
# 220835_s_at                         0.073679
# 216211_at                           0.073673
# 217950_at                           0.073671
# 211170_s_at                         0.073663
# 219535_at                           0.073652
# 201587_s_at                         0.073647
# 203297_s_at                         0.073519
# 201583_s_at                         0.073513
# 213053_at                           0.073349
# 217887_s_at                         0.073285
# 204265_s_at                         0.073270
# 219369_s_at                         0.073263
# 202499_s_at                         0.073215
# 208757_at                           0.072923
# 206896_s_at                         0.072872
# 220540_at                           0.072866
# 215646_s_at                         0.072838
# 203939_at                           0.072808
# 205206_at                           0.072749
# 202725_at                           0.072633
# 207220_at                           0.072615
# 203021_at                           0.072400
# 216953_s_at                         0.072361
# 217188_s_at                         0.072293
# 206374_at                           0.072192
# 208566_at                           0.072126
# 206919_at                           0.071857
# 38766_at                            0.071833
# 219741_x_at                         0.071830
# 209447_at                           0.071709
# 212022_s_at                         0.071669
# 201597_at                           0.071643
# 204073_s_at                         0.071604
# 221294_at                           0.071591
# 208481_at                           0.071540
# 203311_s_at                         0.071521
# 203521_s_at                         0.071386
# 220139_at                           0.071334
# 220856_x_at                         0.071259
# 204849_at                           0.071238
# 206839_at                           0.071199
# 212691_at                           0.071037
# 219157_at                           0.071036
# 219747_at                           0.070986
# 222310_at                           0.070838
# 215527_at                           0.070834
# 214614_at                           0.070782
# 206711_at                           0.070649
# 221751_at                           0.070642
# 213647_at                           0.070393
# 217303_s_at                         0.070158
# 208756_at                           0.070098
# 214458_at                           0.070040
# 220097_s_at                         0.069935
# 221997_s_at                         0.069926
# 204405_x_at                         0.069838
# 218500_at                           0.069753
# 214139_at                           0.069730
# 202581_at                           0.069688
# 214221_at                           0.069657
# 202604_x_at                         0.069579
# 212070_at                           0.069568
# 204641_at                           0.069485
# 211695_x_at                         0.069476
# 202387_at                           0.069433
# 202623_at                           0.069424
# 216221_s_at                         0.069376
# 204692_at                           0.069368
# 207964_x_at                         0.069333
# 37201_at                            0.069293
# 210181_s_at                         0.069219
# 209981_at                           0.069206
# 201519_at                           0.069166
# 206087_x_at                         0.068996
# 204309_at                           0.068914
# 206410_at                           0.068909
# 219253_at                           0.068900
# 208287_at                           0.068876
# 205519_at                           0.068847
# 207526_s_at                         0.068699
# 220159_at                           0.068614
# 203831_at                           0.068571
# 202638_s_at                         0.068554
# 213032_at                           0.068525
# 38703_at                            0.068517
# 201473_at                           0.068447
# 207880_at                           0.068382
# 218322_s_at                         0.068350
# 214367_at                           0.068269
# 215922_at                           0.068264
# 220537_at                           0.068169
# 208653_s_at                         0.067995
# 205471_s_at                         0.067967
# 217073_x_at                         0.067929
# 203254_s_at                         0.067890
# 208910_s_at                         0.067823
# 207854_at                           0.067779
# 212962_at                           0.067712
# 210968_s_at                         0.067697
# 209651_at                           0.067656
# 200695_at                           0.067604
# 213065_at                           0.067582
# 220722_s_at                         0.067518
# 218679_s_at                         0.067466
# 202804_at                           0.067316
# 202034_x_at                         0.067286
# 219973_at                           0.067255
# 217907_at                           0.067239
# 219476_at                           0.067232
# 206310_at                           0.067225
# 201226_at                           0.067054
# 211926_s_at                         0.067045
# 221236_s_at                         0.067038
# 204257_at                           0.066989
# 221608_at                           0.066917
# 207077_at                           0.066851
# 215267_s_at                         0.066836
# 205078_at                           0.066819
# 209945_s_at                         0.066674
# 211626_x_at                         0.066561
# 217615_at                           0.066510
# 202321_at                           0.066456
# 201396_s_at                         0.066441
# 208579_x_at                         0.066415
# 216270_at                           0.066384
# 218474_s_at                         0.066366
# 201700_at                           0.066362
# 207717_s_at                         0.066301
# 207042_at                           0.066292
# 209352_s_at                         0.066281
# 37079_at                            0.066277
# 206158_s_at                         0.066268
# 207564_x_at                         0.066232
# 216969_s_at                         0.066225
# 217571_at                           0.066003
# 200732_s_at                         0.065956
# 201180_s_at                         0.065950
# 211880_x_at                         0.065941
# 206540_at                           0.065934
# PATHOLOGIC_N_STAGE                  0.065906
# 210915_x_at                         0.065886
# 211775_x_at                         0.065880
# 200600_at                           0.065872
# 208152_s_at                         0.065789
# 201447_at                           0.065777
# 213437_at                           0.065629
# 218962_s_at                         0.065574
# 205022_s_at                         0.065526
# 214740_at                           0.065444
# 214104_at                           0.065393
# 222190_s_at                         0.065326
# 210848_at                           0.065296
# 203461_at                           0.065284
# 211222_s_at                         0.065170
# 209031_at                           0.065163
# 207287_at                           0.065125
# 205863_at                           0.065124
# 219388_at                           0.065123
# 207103_at                           0.065005
# 207278_s_at                         0.064996
# 220010_at                           0.064990
# 201147_s_at                         0.064973
# 220224_at                           0.064951
# 209231_s_at                         0.064933
# 206218_at                           0.064838
# 206820_at                           0.064747
# 213565_s_at                         0.064723
# 220832_at                           0.064612
# 221370_at                           0.064605
# 213360_s_at                         0.064596
# 208375_at                           0.064593
# 219590_x_at                         0.064546
# 213307_at                           0.064520
# 218890_x_at                         0.064452
# 219682_s_at                         0.064385
# 206935_at                           0.064349
# 218596_at                           0.064283
# 202780_at                           0.064268
# 214498_at                           0.064168
# 216886_at                           0.064114
# 219908_at                           0.064082
# 215631_s_at                         0.064011
# 214086_s_at                         0.063951
# 208339_at                           0.063947
# 209977_at                           0.063935
# 220318_at                           0.063911
# 213340_s_at                         0.063902
# 208614_s_at                         0.063851
# 209253_at                           0.063835
# 211330_s_at                         0.063739
# 209717_at                           0.063726
# 216034_at                           0.063661
# 218025_s_at                         0.063639
# 206197_at                           0.063529
# 208876_s_at                         0.063298
# 208354_s_at                         0.063280
# 201496_x_at                         0.063244
# 201152_s_at                         0.063229
# 214919_s_at                         0.063209
# 218148_at                           0.063175
# 209709_s_at                         0.063146
# 208896_at                           0.063063
# 90265_at                            0.063032
# 203959_s_at                         0.063004
# 220755_s_at                         0.062986
# 218334_at                           0.062918
# 216229_x_at                         0.062856
# 212327_at                           0.062823
# 215578_at                           0.062807
# 210272_at                           0.062802
# 215034_s_at                         0.062792
# 200908_s_at                         0.062732
# 212197_x_at                         0.062678
# 207460_at                           0.062666
# 220562_at                           0.062623
# 217509_x_at                         0.062622
# 221757_at                           0.062621
# 210942_s_at                         0.062425
# 211467_s_at                         0.062419
# 201123_s_at                         0.062403
# 220256_s_at                         0.062397
# 220345_at                           0.062385
# 215112_x_at                         0.062357
# 208033_s_at                         0.062311
# 214354_x_at                         0.062266
# 218690_at                           0.062253
# 211323_s_at                         0.062171
# 218617_at                           0.062096
# 210990_s_at                         0.062079
# 213673_x_at                         0.062067
# 217110_s_at                         0.062063
# 202124_s_at                         0.062040
# 209202_s_at                         0.062020
# 215732_s_at                         0.062010
# 214726_x_at                         0.061974
# 213772_s_at                         0.061931
# 208159_x_at                         0.061902
# 219430_at                           0.061887
# 214320_x_at                         0.061844
# 212481_s_at                         0.061825
# 206114_at                           0.061780
# 220457_at                           0.061769
# 203391_at                           0.061739
# 203278_s_at                         0.061685
# 210331_at                           0.061648
# 211900_x_at                         0.061501
# 222373_at                           0.061444
# 823_at                              0.061423
# 205613_at                           0.061410
# 205103_at                           0.061348
# 206689_x_at                         0.061294
# 214562_at                           0.061279
# 202927_at                           0.061260
# 214807_at                           0.061253
# 208546_x_at                         0.061219
# 218181_s_at                         0.061209
# 212708_at                           0.061200
# 221991_at                           0.061192
# 220598_at                           0.061073
# 209762_x_at                         0.061072
# 220962_s_at                         0.061058
# 204123_at                           0.061038
# 208532_x_at                         0.060907
# 216475_at                           0.060874
# 217583_at                           0.060836
# 200051_at                           0.060828
# 216008_s_at                         0.060802
# 214792_x_at                         0.060774
# 204703_at                           0.060765
# 220079_s_at                         0.060718
# 213584_s_at                         0.060645
# 219664_s_at                         0.060633
# 204170_s_at                         0.060619
# 220072_at                           0.060568
# 205602_x_at                         0.060545
# 204258_at                           0.060470
# 215143_at                           0.060460
# 209891_at                           0.060397
# 218927_s_at                         0.060386
# 218689_at                           0.060296
# 206500_s_at                         0.060278
# 213156_at                           0.060258
# 201373_at                           0.060257
# 210129_s_at                         0.060239
# 220148_at                           0.060215
# 203372_s_at                         0.060215
# 212668_at                           0.060174
# 208071_s_at                         0.060172
# 202834_at                           0.060148
# 216251_s_at                         0.060130
# 211260_at                           0.060076
# 210493_s_at                         0.060065
# 211800_s_at                         0.060016
# 209087_x_at                         0.059966
# 212339_at                           0.059907
# 200966_x_at                         0.059877
# 204047_s_at                         0.059847
# 215739_s_at                         0.059844
# 218779_x_at                         0.059809
# 208509_s_at                         0.059801
# 209110_s_at                         0.059767
# 219856_at                           0.059575
# 206687_s_at                         0.059570
# 214175_x_at                         0.059564
# 208323_s_at                         0.059544
# 215916_at                           0.059534
# 213811_x_at                         0.059530
# 210495_x_at                         0.059506
# 210427_x_at                         0.059476
# 211148_s_at                         0.059416
# 207031_at                           0.059392
# 209067_s_at                         0.059354
# 221207_s_at                         0.059248
# 205577_at                           0.059197
# 202722_s_at                         0.059169
# 216687_x_at                         0.059140
# 205468_s_at                         0.059119
# 202853_s_at                         0.059103
# 217407_x_at                         0.059092
# 210681_s_at                         0.059084
# 202039_at                           0.059057
# 221661_at                           0.059046
# 211992_at                           0.059028
# 210808_s_at                         0.059012
# 208841_s_at                         0.059000
# 209682_at                           0.058905
# 203374_s_at                         0.058905
# 203667_at                           0.058803
# 209519_at                           0.058799
# 218742_at                           0.058763
# 221672_s_at                         0.058707
# 202470_s_at                         0.058639
# 207017_at                           0.058628
# 214141_x_at                         0.058590
# 219243_at                           0.058561
# 218529_at                           0.058500
# 202258_s_at                         0.058497
# 210397_at                           0.058473
# 208463_at                           0.058450
# 217038_at                           0.058449
# 221271_at                           0.058434
# 201556_s_at                         0.058410
# 217098_s_at                         0.058357
# 200661_at                           0.058294
# 215072_x_at                         0.058256
# 207336_at                           0.058248
# 207877_s_at                         0.058227
# 213732_at                           0.058223
# 214111_at                           0.058183
# 217014_s_at                         0.058150
# 209713_s_at                         0.058148
# 214525_x_at                         0.058119
# 207868_at                           0.058061
# 206279_at                           0.058035
# 222036_s_at                         0.058028
# 214876_s_at                         0.057997
# 204681_s_at                         0.057950
# 208848_at                           0.057922
# 209825_s_at                         0.057867
# 210853_at                           0.057846
# 212225_at                           0.057826
# 217192_s_at                         0.057806
# 210471_s_at                         0.057805
# 212052_s_at                         0.057787
# 206564_at                           0.057768
# 211709_s_at                         0.057739
# 220964_s_at                         0.057706
# 208539_x_at                         0.057690
# 201690_s_at                         0.057680
# 218418_s_at                         0.057638
# 219671_at                           0.057637
# 220190_s_at                         0.057573
# 205634_x_at                         0.057572
# 207721_x_at                         0.057567
# 209430_at                           0.057553
# 216129_at                           0.057547
# 219691_at                           0.057509
# 211813_x_at                         0.057506
# 215517_at                           0.057482
# 217323_at                           0.057462
# 220157_x_at                         0.057448
# 217662_x_at                         0.057404
# 221907_at                           0.057395
# 217853_at                           0.057352
# 200050_at                           0.057332
# 217968_at                           0.057326
# 215859_at                           0.057306
# 201940_at                           0.057304
# 216982_x_at                         0.057295
# 220862_s_at                         0.057252
# 218184_at                           0.057236
# 210728_s_at                         0.057198
# 210268_at                           0.057187
# 214642_x_at                         0.057165
# 220605_s_at                         0.057160
# 218498_s_at                         0.057104
# 206574_s_at                         0.057100
# 205636_at                           0.057087
# 218430_s_at                         0.057087
# 204530_s_at                         0.056998
# 222114_x_at                         0.056979
# 218744_s_at                         0.056974
# 201475_x_at                         0.056963
# 203806_s_at                         0.056926
# 207129_at                           0.056925
# 211160_x_at                         0.056896
# 218121_at                           0.056892
# 220824_at                           0.056872
# 202708_s_at                         0.056843
# 200635_s_at                         0.056827
# 206409_at                           0.056820
# 202726_at                           0.056797
# 213058_at                           0.056783
# 218796_at                           0.056748
# 221887_s_at                         0.056738
# 218327_s_at                         0.056713
# 202351_at                           0.056699
# 210638_s_at                         0.056682
# 200656_s_at                         0.056676
# 201070_x_at                         0.056673
# 212229_s_at                         0.056665
# 219405_at                           0.056646
# 215248_at                           0.056631
# 214934_at                           0.056582
# 203335_at                           0.056556
# 215439_x_at                         0.056533
# 214233_at                           0.056512
# 35147_at                            0.056511
# 200817_x_at                         0.056443
# 217554_at                           0.056440
# 214963_at                           0.056438
# 203908_at                           0.056420
# 215291_at                           0.056418
# 211583_x_at                         0.056407
# 203707_at                           0.056372
# 211700_s_at                         0.056344
# 218256_s_at                         0.056313
# 201234_at                           0.056302
# 206252_s_at                         0.056299
# 204529_s_at                         0.056297
# 213780_at                           0.056295
# 201859_at                           0.056271
# 202163_s_at                         0.056269
# 213814_s_at                         0.056262
# 222315_at                           0.056221
# 205884_at                           0.056213
# 221925_s_at                         0.056200
# 215157_x_at                         0.056165
# 221317_x_at                         0.056138
# 213669_at                           0.056129
# 210692_s_at                         0.056128
# 218212_s_at                         0.056120
# 203995_at                           0.056085
# 203027_s_at                         0.056066
# 203573_s_at                         0.056061
# 208952_s_at                         0.056059
# 214072_x_at                         0.056042
# 211758_x_at                         0.056004
# 220397_at                           0.056002
# 201714_at                           0.055986
# 202584_at                           0.055978
# 202813_at                           0.055936
# 217695_x_at                         0.055909
# 207760_s_at                         0.055906
# 216758_at                           0.055888
# 218995_s_at                         0.055880
# 222274_at                           0.055843
# 214851_at                           0.055820
# 201961_s_at                         0.055813
# 208137_x_at                         0.055777
# 212901_s_at                         0.055753
# 220469_at                           0.055646
# 200079_s_at                         0.055642
# 215610_at                           0.055501
# 213730_x_at                         0.055501
# 209019_s_at                         0.055492
# 218073_s_at                         0.055484
# 33579_i_at                          0.055470
# 219364_at                           0.055376
# 210753_s_at                         0.055319
# 220529_at                           0.055306
# 202528_at                           0.055297
# 220768_s_at                         0.055295
# 202860_at                           0.055295
# 204124_at                           0.055270
# 217039_x_at                         0.055240
# 203933_at                           0.055232
# 206001_at                           0.055224
# 202893_at                           0.055185
# 210195_s_at                         0.055165
# 201676_x_at                         0.055141
# 220401_at                           0.055096
# 204745_x_at                         0.055067
# 206173_x_at                         0.055062
# 207756_at                           0.055058
# 200948_at                           0.055041
# 33307_at                            0.055011
# 212328_at                           0.055010
# 207747_s_at                         0.055007
# 217667_at                           0.054917
# 204978_at                           0.054893
# 205947_s_at                         0.054874
# 216295_s_at                         0.054863
# 216920_s_at                         0.054842
# 222271_at                           0.054838
# 218784_s_at                         0.054807
# 203822_s_at                         0.054777
# 220734_s_at                         0.054774
# 202739_s_at                         0.054759
# 206830_at                           0.054633
# 218939_at                           0.054623
# 201617_x_at                         0.054610
# 201545_s_at                         0.054551
# 205290_s_at                         0.054525
# 208502_s_at                         0.054423
# 216046_at                           0.054367
# 202887_s_at                         0.054349
# 222309_at                           0.054333
# 221084_at                           0.054314
# 213587_s_at                         0.054290
# 201608_s_at                         0.054257
# 200608_s_at                         0.054241
# 216765_at                           0.054188
# 213208_at                           0.054179
# 220555_s_at                         0.054177
# 214576_at                           0.054155
# 222313_at                           0.054134
# 201157_s_at                         0.054113
# 205929_at                           0.054104
# 203564_at                           0.054103
# 222331_at                           0.054099
# 205396_at                           0.054097
# 220620_at                           0.054066
# 205028_at                           0.054033
# 210998_s_at                         0.054032
# PATHOLOGIC_T_STAGE                  0.053985
# 207676_at                           0.053969
# 211682_x_at                         0.053963
# 219925_at                           0.053958
# 209715_at                           0.053950
# 218813_s_at                         0.053882
# 216958_s_at                         0.053822
# 210214_s_at                         0.053799
# 222276_at                           0.053795
# 215520_at                           0.053785
# 221019_s_at                         0.053746
# 209251_x_at                         0.053658
# 212979_s_at                         0.053634
# 215251_at                           0.053613
# 219768_at                           0.053604
# 207280_at                           0.053599
# 204766_s_at                         0.053585
# 207730_x_at                         0.053576
# 205357_s_at                         0.053533
# 207657_x_at                         0.053479
# 218307_at                           0.053469
# 215258_at                           0.053463
# 217580_x_at                         0.053447
# 217997_at                           0.053395
# 214157_at                           0.053386
# 218853_s_at                         0.053371
# 202232_s_at                         0.053346
# 216135_at                           0.053309
# 212195_at                           0.053291
# 202705_at                           0.053279
# 218674_at                           0.053277
# 213476_x_at                         0.053261
# 204455_at                           0.053259
# 203765_at                           0.053240
# 200595_s_at                         0.053169
# 201159_s_at                         0.053160
# 213832_at                           0.053150
# 214380_at                           0.053121
# 217543_s_at                         0.053116
# 213580_at                           0.053105
# 218615_s_at                         0.053090
# 204476_s_at                         0.053089
# 208572_at                           0.053069
# 219699_at                           0.053060
# 215808_at                           0.053057
# 219139_s_at                         0.053014
# 215046_at                           0.052972
# 218353_at                           0.052971
# 212257_s_at                         0.052963
# 212570_at                           0.052942
# 208115_x_at                         0.052938
# 214718_at                           0.052928
# 215987_at                           0.052911
# 207223_s_at                         0.052870
# 213875_x_at                         0.052866
# 204545_at                           0.052865
# 210312_s_at                         0.052840
# 214906_x_at                         0.052812
# 218831_s_at                         0.052806
# 213515_x_at                         0.052803
# 219144_at                           0.052770
# 217656_at                           0.052753
# 208511_at                           0.052745
# 217401_at                           0.052742
# 221580_s_at                         0.052714
# 65630_at                            0.052667
# 211146_at                           0.052665
# 214168_s_at                         0.052662
# 203741_s_at                         0.052661
# 205966_at                           0.052643
# 214480_at                           0.052631
# 201322_at                           0.052621
# 216551_x_at                         0.052611
# 217966_s_at                         0.052593
# 203450_at                           0.052582
# 206785_s_at                         0.052576
# 202768_at                           0.052554
# 207092_at                           0.052540
# 212105_s_at                         0.052530
# 208936_x_at                         0.052529
# 204822_at                           0.052502
# 215199_at                           0.052498
# 205916_at                           0.052486
# 216327_s_at                         0.052470
# 219640_at                           0.052459
# 209523_at                           0.052452
# 217697_at                           0.052415
# 216354_at                           0.052389
# 204141_at                           0.052388
# 213268_at                           0.052353
# 207740_s_at                         0.052337
# 200689_x_at                         0.052328
# 215323_at                           0.052298
# 205785_at                           0.052293
# 204028_s_at                         0.052291
# 201254_x_at                         0.052278
# 219260_s_at                         0.052256
# 205587_at                           0.052254
# 202236_s_at                         0.052243
# 201201_at                           0.052243
# 200977_s_at                         0.052225
# 220730_at                           0.052212
# 205753_at                           0.052206
# 206512_at                           0.052133
# 201328_at                           0.052094
# 216249_at                           0.052093
# 202734_at                           0.052083
# 204062_s_at                         0.052078
# 215779_s_at                         0.052014
# 211200_s_at                         0.052013
# 201398_s_at                         0.052011
# 218250_s_at                         0.052001
# 216558_x_at                         0.052001
# 218365_s_at                         0.051988
# 210329_s_at                         0.051973
# 208908_s_at                         0.051964
# 220164_s_at                         0.051958
# 220682_s_at                         0.051886
# 203542_s_at                         0.051882
# 208812_x_at                         0.051875
# 220833_at                           0.051872
# 221983_at                           0.051865
# 218439_s_at                         0.051862
# 202195_s_at                         0.051853
# 210685_s_at                         0.051850
# 207398_at                           0.051825
# 204866_at                           0.051756
# 219313_at                           0.051711
# 200785_s_at                         0.051707
# 65588_at                            0.051688
# 208724_s_at                         0.051669
# 220763_at                           0.051668
# 202294_at                           0.051655
# 217765_at                           0.051651
# 206632_s_at                         0.051633
# 203106_s_at                         0.051632
# 206113_s_at                         0.051628
# 206213_at                           0.051626
# 213755_s_at                         0.051601
# 202422_s_at                         0.051581
# 213680_at                           0.051523
# 207488_at                           0.051511
# 201282_at                           0.051504
# 219824_at                           0.051500
# 212431_at                           0.051482
# 215568_x_at                         0.051477
# 209370_s_at                         0.051467
# 202314_at                           0.051455
# 214700_x_at                         0.051439
# 219002_at                           0.051437
# 213010_at                           0.051431
# 203805_s_at                         0.051403
# 202091_at                           0.051392
# 202520_s_at                         0.051374
# 202855_s_at                         0.051361
# 209024_s_at                         0.051343
# 218713_at                           0.051325
# 214201_x_at                         0.051304
# 201469_s_at                         0.051304
# 221249_s_at                         0.051280
# 217409_at                           0.051275
# 206479_at                           0.051229
# 217924_at                           0.051221
# 212088_at                           0.051206
# 213872_at                           0.051200
# 211988_at                           0.051188
# 213628_at                           0.051181
# 219670_at                           0.051160
# 56748_at                            0.051159
# 210977_s_at                         0.051139
# 214610_at                           0.051133
# 214134_at                           0.051122
# 202795_x_at                         0.051120
# 214156_at                           0.051119
# 214791_at                           0.051112
# 213181_s_at                         0.051104
# 203463_s_at                         0.051098
# 201135_at                           0.051073
# 204916_at                           0.051055
# 202622_s_at                         0.051052
# 214340_at                           0.051051
# 203563_at                           0.051037
# 213242_x_at                         0.051031
# 32099_at                            0.051026
# 216066_at                           0.051020
# 208563_x_at                         0.051001
# 203646_at                           0.050996
# 208227_x_at                         0.050992
# 208753_s_at                         0.050979
# 209800_at                           0.050954
# 201814_at                           0.050945
# 212918_at                           0.050944
# 209948_at                           0.050930
# 220476_s_at                         0.050929
# 221314_at                           0.050914
# 217807_s_at                         0.050862
# 202618_s_at                         0.050861
# 210810_s_at                         0.050860
# 213310_at                           0.050857
# 204188_s_at                         0.050836
# 204730_at                           0.050832
# 209498_at                           0.050830
# 213921_at                           0.050826
# 205664_at                           0.050819
# 211438_at                           0.050816
# 203882_at                           0.050812
# 216159_s_at                         0.050811
# 221169_s_at                         0.050810
# 204015_s_at                         0.050806
# 200950_at                           0.050799
# 209243_s_at                         0.050798
# 201871_s_at                         0.050787
# 210644_s_at                         0.050731
# 202958_at                           0.050729
# 205980_s_at                         0.050723
# 204814_at                           0.050712
# 211042_x_at                         0.050672
# 221032_s_at                         0.050655
# 222088_s_at                         0.050636
# 216692_at                           0.050627
# 202955_s_at                         0.050607
# 203223_at                           0.050604
# 204670_x_at                         0.050585
# FIRST_PROGRESSION_OR_RELAPSE        0.050566
# 217426_at                           0.050545
# 220717_at                           0.050533
# 219332_at                           0.050533
# 214776_x_at                         0.050509
# 220452_x_at                         0.050492
# 204773_at                           0.050479
# 202391_at                           0.050471
# 206902_s_at                         0.050413
# 210772_at                           0.050409
# 204067_at                           0.050387
# 214083_at                           0.050384
# 217404_s_at                         0.050378
# 214874_at                           0.050339
# 218087_s_at                         0.050337
# 202885_s_at                         0.050336
# 211752_s_at                         0.050310
# 217955_at                           0.050307
# 200847_s_at                         0.050303
# 219472_at                           0.050302
# 209188_x_at                         0.050297
# 203227_s_at                         0.050276
# 211469_s_at                         0.050263
# 211740_at                           0.050246
# 218925_s_at                         0.050239
# 206102_at                           0.050232
# 208196_x_at                         0.050187
# 208698_s_at                         0.050182
# 206733_at                           0.050153
# 204128_s_at                         0.050143
# 208368_s_at                         0.050069
# 220641_at                           0.050045
# 202841_x_at                         0.049998
# 212193_s_at                         0.049995
# 209156_s_at                         0.049992
# 218072_at                           0.049979
# 210646_x_at                         0.049929
# 218726_at                           0.049910
# 213594_x_at                         0.049907
# 211666_x_at                         0.049895
# 219546_at                           0.049894
# 217312_s_at                         0.049883
# 219041_s_at                         0.049876
# 200828_s_at                         0.049873
# 214428_x_at                         0.049865
# 210547_x_at                         0.049855
# 221621_at                           0.049850
# 211919_s_at                         0.049848
# 204151_x_at                         0.049846
# 222242_s_at                         0.049827
# 205257_s_at                         0.049823
# 219781_s_at                         0.049815
# 207925_at                           0.049802
# 216173_at                           0.049793
# 201816_s_at                         0.049723
# 218947_s_at                         0.049714
# 212812_at                           0.049707
# 217326_x_at                         0.049698
# 201052_s_at                         0.049656
# 207581_s_at                         0.049656
# 218062_x_at                         0.049630
# 210358_x_at                         0.049611
# 205198_s_at                         0.049575
# 216952_s_at                         0.049549
# 201436_at                           0.049539
# 204843_s_at                         0.049520
# 201803_at                           0.049497
# 202132_at                           0.049484
# 204228_at                           0.049462
# 222194_at                           0.049452
# 216264_s_at                         0.049450
# 211199_s_at                         0.049448
# 215530_at                           0.049439
# 206144_at                           0.049417
# 209999_x_at                         0.049415
# 32088_at                            0.049414
# 204252_at                           0.049410
# AFFX-CreX-5_at                      0.049402
# 209359_x_at                         0.049396
# 211377_x_at                         0.049394
# 221002_s_at                         0.049384
# 216713_at                           0.049383
# 215154_at                           0.049380
# 207993_s_at                         0.049365
# 212265_at                           0.049312
# 213003_s_at                         0.049295
# 210839_s_at                         0.049279
# 213378_s_at                         0.049279
# 219371_s_at                         0.049278
# 213897_s_at                         0.049276
# 218841_at                           0.049232
# 200722_s_at                         0.049227
# 220915_s_at                         0.049224
# 215201_at                           0.049201
# 221282_x_at                         0.049175
# 213646_x_at                         0.049170
# 214251_s_at                         0.049169
# 214887_at                           0.049166
# 221457_s_at                         0.049135
# 201484_at                           0.049115
# 212807_s_at                         0.049111
# 204909_at                           0.049103
# 214720_x_at                         0.049101
# 202737_s_at                         0.049087
# 204687_at                           0.049069
# 207279_s_at                         0.049046
# 222317_at                           0.049027
# 215608_at                           0.049013
# 212981_s_at                         0.048990
# 216804_s_at                         0.048981
# 208855_s_at                         0.048972
# 202469_s_at                         0.048956
# 217926_at                           0.048956
# 206316_s_at                         0.048940
# 215882_at                           0.048935
# 213757_at                           0.048926
# 204106_at                           0.048917
# 40189_at                            0.048860
# 202635_s_at                         0.048855
# 213457_at                           0.048850
# 207082_at                           0.048841
# 220273_at                           0.048838
# 206910_x_at                         0.048835
# 204131_s_at                         0.048833
# 211699_x_at                         0.048805
# 203048_s_at                         0.048795
# 201505_at                           0.048792
# 218139_s_at                         0.048775
# 203855_at                           0.048762
# 208536_s_at                         0.048742
# 212831_at                           0.048735
# 200714_x_at                         0.048694
# 217430_x_at                         0.048683
# 209932_s_at                         0.048664
# 209542_x_at                         0.048661
# 202691_at                           0.048638
# 204444_at                           0.048614
# 205734_s_at                         0.048598
# 216198_at                           0.048589
# 210849_s_at                         0.048583
# 213796_at                           0.048581
# 37577_at                            0.048571
# 207682_s_at                         0.048533
# 208826_x_at                         0.048520
# 210357_s_at                         0.048513
# 220475_at                           0.048403
# 205702_at                           0.048399
# 203931_s_at                         0.048364
# ...
# 210226_at                           0.000000
# 210227_at                           0.000000
# 210229_s_at                         0.000000
# 210230_at                           0.000000
# 210231_x_at                         0.000000
# 210232_at                           0.000000
# 210072_at                           0.000000
# 210069_at                           0.000000
# 210290_at                           0.000000
# 209907_s_at                         0.000000
# 209912_s_at                         0.000000
# 209915_s_at                         0.000000
# 209916_at                           0.000000
# 209917_s_at                         0.000000
# 209920_at                           0.000000
# 209922_at                           0.000000
# 209924_at                           0.000000
# 209925_at                           0.000000
# 209926_at                           0.000000
# 209927_s_at                         0.000000
# 209928_s_at                         0.000000
# 209929_s_at                         0.000000
# 209930_s_at                         0.000000
# 209931_s_at                         0.000000
# 209933_s_at                         0.000000
# 209935_at                           0.000000
# 209936_at                           0.000000
# 209938_at                           0.000000
# 209950_s_at                         0.000000
# 209951_s_at                         0.000000
# 209953_s_at                         0.000000
# 209957_s_at                         0.000000
# 209958_s_at                         0.000000
# 209959_at                           0.000000
# 209964_s_at                         0.000000
# 209910_at                           0.000000
# 209904_at                           0.000000
# 209968_s_at                         0.000000
# 209902_at                           0.000000
# 209852_x_at                         0.000000
# 209855_s_at                         0.000000
# 209858_x_at                         0.000000
# 209860_s_at                         0.000000
# 209862_s_at                         0.000000
# 209864_at                           0.000000
# 209867_s_at                         0.000000
# 209868_s_at                         0.000000
# 209871_s_at                         0.000000
# 209872_s_at                         0.000000
# 209874_x_at                         0.000000
# 209875_s_at                         0.000000
# 209876_at                           0.000000
# 209877_at                           0.000000
# 209878_s_at                         0.000000
# 209880_s_at                         0.000000
# 209881_s_at                         0.000000
# 209885_at                           0.000000
# 209887_at                           0.000000
# 209888_s_at                         0.000000
# 209889_at                           0.000000
# 209893_s_at                         0.000000
# 209894_at                           0.000000
# 209896_s_at                         0.000000
# 209899_s_at                         0.000000
# 209967_s_at                         0.000000
# 209970_x_at                         0.000000
# 210068_s_at                         0.000000
# 210025_s_at                         0.000000
# 210028_s_at                         0.000000
# 210032_s_at                         0.000000
# 210034_s_at                         0.000000
# 210038_at                           0.000000
# 210039_s_at                         0.000000
# 210040_at                           0.000000
# 210041_s_at                         0.000000
# 210044_s_at                         0.000000
# 210045_at                           0.000000
# 210047_at                           0.000000
# 210048_at                           0.000000
# 210049_at                           0.000000
# 210050_at                           0.000000
# 210051_at                           0.000000
# 210052_s_at                         0.000000
# 210053_at                           0.000000
# 210054_at                           0.000000
# 210056_at                           0.000000
# 210058_at                           0.000000
# 210059_s_at                         0.000000
# 210061_at                           0.000000
# 210063_at                           0.000000
# 210065_s_at                         0.000000
# 210066_s_at                         0.000000
# 210067_at                           0.000000
# 210027_s_at                         0.000000
# 210023_s_at                         0.000000
# 209972_s_at                         0.000000
# 210020_x_at                         0.000000
# 209973_at                           0.000000
# 209974_s_at                         0.000000
# 209975_at                           0.000000
# 209978_s_at                         0.000000
# 209979_at                           0.000000
# 209980_s_at                         0.000000
# 209982_s_at                         0.000000
# 209984_at                           0.000000
# 209985_s_at                         0.000000
# 209986_at                           0.000000
# 209988_s_at                         0.000000
# 209990_s_at                         0.000000
# 209991_x_at                         0.000000
# 209992_at                           0.000000
# 209996_x_at                         0.000000
# 209997_x_at                         0.000000
# 209998_at                           0.000000
# 210001_s_at                         0.000000
# 210002_at                           0.000000
# 210005_at                           0.000000
# 210007_s_at                         0.000000
# 210009_s_at                         0.000000
# 210012_s_at                         0.000000
# 210014_x_at                         0.000000
# 210019_at                           0.000000
# 210289_at                           0.000000
# 210292_s_at                         0.000000
# 210751_s_at                         0.000000
# 210583_at                           0.000000
# 210586_x_at                         0.000000
# 210588_x_at                         0.000000
# 210592_s_at                         0.000000
# 210593_at                           0.000000
# 210594_x_at                         0.000000
# 210595_at                           0.000000
# 210599_at                           0.000000
# 210600_s_at                         0.000000
# 210601_at                           0.000000
# 210604_at                           0.000000
# 210605_s_at                         0.000000
# 210607_at                           0.000000
# 210608_s_at                         0.000000
# 210609_s_at                         0.000000
# 210610_at                           0.000000
# 210611_s_at                         0.000000
# 210612_s_at                         0.000000
# 210615_at                           0.000000
# 210617_at                           0.000000
# 210620_s_at                         0.000000
# 210621_s_at                         0.000000
# 210627_s_at                         0.000000
# 210630_s_at                         0.000000
# 210633_x_at                         0.000000
# 210634_at                           0.000000
# 210585_s_at                         0.000000
# 210580_x_at                         0.000000
# 210636_at                           0.000000
# 210579_s_at                         0.000000
# 210521_s_at                         0.000000
# 210524_x_at                         0.000000
# 210525_x_at                         0.000000
# 210529_s_at                         0.000000
# 210531_at                           0.000000
# 210532_s_at                         0.000000
# 210534_s_at                         0.000000
# 210535_at                           0.000000
# 210536_s_at                         0.000000
# 210538_s_at                         0.000000
# 210542_s_at                         0.000000
# 210543_s_at                         0.000000
# 210544_s_at                         0.000000
# 210546_x_at                         0.000000
# 210551_s_at                         0.000000
# 210552_s_at                         0.000000
# 210555_s_at                         0.000000
# 210556_at                           0.000000
# 210557_x_at                         0.000000
# 210558_at                           0.000000
# 210559_s_at                         0.000000
# 210562_at                           0.000000
# 210563_x_at                         0.000000
# 210565_at                           0.000000
# 210569_s_at                         0.000000
# 210635_s_at                         0.000000
# 210640_s_at                         0.000000
# 210519_s_at                         0.000000
# 210704_at                           0.000000
# 210709_at                           0.000000
# 210711_at                           0.000000
# 210715_s_at                         0.000000
# 210716_s_at                         0.000000
# 210717_at                           0.000000
# 210718_s_at                         0.000000
# 210719_s_at                         0.000000
# 210721_s_at                         0.000000
# 210722_at                           0.000000
# 210726_at                           0.000000
# 210727_at                           0.000000
# 210729_at                           0.000000
# 210730_s_at                         0.000000
# 210731_s_at                         0.000000
# 210734_x_at                         0.000000
# 210735_s_at                         0.000000
# 210737_at                           0.000000
# 210740_s_at                         0.000000
# 210743_s_at                         0.000000
# 210744_s_at                         0.000000
# 210745_at                           0.000000
# 210746_s_at                         0.000000
# 210748_at                           0.000000
# 210749_x_at                         0.000000
# 210750_s_at                         0.000000
# 210708_x_at                         0.000000
# 210703_at                           0.000000
# 210642_at                           0.000000
# 210702_s_at                         0.000000
# 210643_at                           0.000000
# 210647_x_at                         0.000000
# 210650_s_at                         0.000000
# 210651_s_at                         0.000000
# 210655_s_at                         0.000000
# 210656_at                           0.000000
# 210657_s_at                         0.000000
# 210661_at                           0.000000
# 210663_s_at                         0.000000
# 210664_s_at                         0.000000
# 210665_at                           0.000000
# 210671_x_at                         0.000000
# 210674_s_at                         0.000000
# 210675_s_at                         0.000000
# 210676_x_at                         0.000000
# 210677_at                           0.000000
# 210678_s_at                         0.000000
# 210682_at                           0.000000
# 210684_s_at                         0.000000
# 210687_at                           0.000000
# 210691_s_at                         0.000000
# 210693_at                           0.000000
# 210694_s_at                         0.000000
# 210695_s_at                         0.000000
# 210698_at                           0.000000
# 210520_at                           0.000000
# 210518_at                           0.000000
# 210294_at                           0.000000
# 210341_at                           0.000000
# 210346_s_at                         0.000000
# 210347_s_at                         0.000000
# 210348_at                           0.000000
# 210349_at                           0.000000
# 210354_at                           0.000000
# 210356_x_at                         0.000000
# 210359_at                           0.000000
# 210360_s_at                         0.000000
# 210362_x_at                         0.000000
# 210366_at                           0.000000
# 210367_s_at                         0.000000
# 210372_s_at                         0.000000
# 210373_at                           0.000000
# 210379_s_at                         0.000000
# 210380_s_at                         0.000000
# 210382_at                           0.000000
# 210385_s_at                         0.000000
# 210387_at                           0.000000
# 210390_s_at                         0.000000
# 210391_at                           0.000000
# 210394_x_at                         0.000000
# 210395_x_at                         0.000000
# 210396_s_at                         0.000000
# 210398_x_at                         0.000000
# 210399_x_at                         0.000000
# 210345_s_at                         0.000000
# 210339_s_at                         0.000000
# 210402_at                           0.000000
# 210338_s_at                         0.000000
# 210296_s_at                         0.000000
# 210298_x_at                         0.000000
# 210299_s_at                         0.000000
# 210301_at                           0.000000
# 210303_at                           0.000000
# 210304_at                           0.000000
# 210305_at                           0.000000
# 210306_at                           0.000000
# 210307_s_at                         0.000000
# 210309_at                           0.000000
# 210311_at                           0.000000
# 210313_at                           0.000000
# 210315_at                           0.000000
# 210316_at                           0.000000
# 210317_s_at                         0.000000
# 210320_s_at                         0.000000
# 210322_x_at                         0.000000
# 210323_at                           0.000000
# 210324_at                           0.000000
# 210327_s_at                         0.000000
# 210332_at                           0.000000
# 210333_at                           0.000000
# 210335_at                           0.000000
# 210336_x_at                         0.000000
# 210337_s_at                         0.000000
# 210401_at                           0.000000
# 210403_s_at                         0.000000
# 210516_at                           0.000000
# 210449_x_at                         0.000000
# 210454_s_at                         0.000000
# 210457_x_at                         0.000000
# 210459_at                           0.000000
# 210462_at                           0.000000
# 210464_at                           0.000000
# 210467_x_at                         0.000000
# 210469_at                           0.000000
# 210470_x_at                         0.000000
# 210474_s_at                         0.000000
# 210475_at                           0.000000
# 210477_x_at                         0.000000
# 210479_s_at                         0.000000
# 210483_at                           0.000000
# 210486_at                           0.000000
# 210487_at                           0.000000
# 210492_at                           0.000000
# 210499_s_at                         0.000000
# 210501_x_at                         0.000000
# 210503_at                           0.000000
# 210504_at                           0.000000
# 210505_at                           0.000000
# 210506_at                           0.000000
# 210507_s_at                         0.000000
# 210508_s_at                         0.000000
# 210514_x_at                         0.000000
# 210453_x_at                         0.000000
# 210448_s_at                         0.000000
# 210404_x_at                         0.000000
# 210445_at                           0.000000
# 210406_s_at                         0.000000
# 210411_s_at                         0.000000
# 210414_at                           0.000000
# 210415_s_at                         0.000000
# 210418_s_at                         0.000000
# 210419_at                           0.000000
# 210420_at                           0.000000
# 210421_s_at                         0.000000
# 210422_x_at                         0.000000
# 210424_s_at                         0.000000
# 210425_x_at                         0.000000
# 210426_x_at                         0.000000
# 210429_at                           0.000000
# 210430_x_at                         0.000000
# 210431_at                           0.000000
# 210432_s_at                         0.000000
# 210433_at                           0.000000
# 210434_x_at                         0.000000
# 210435_at                           0.000000
# 210437_at                           0.000000
# 210438_x_at                         0.000000
# 210440_s_at                         0.000000
# 210441_at                           0.000000
# 210442_at                           0.000000
# 210443_x_at                         0.000000
# 211756_at                           0.000000
# dtype: float64

# %%
from sklearn.feature_selection import SelectKBest
#No we Will select the  top 5 important features
sel_five_cols = SelectKBest(mutual_info_classif, k=1500)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['200045_at', '200047_s_at', '200050_at', '200051_at', '200079_s_at',
#        '200595_s_at', '200600_at', '200608_s_at', '200620_at', '200623_s_at',
#        ...
#        'AFFX-CreX-5_at', 'AFFX-HUMGAPDH/M33197_M_at', 'AFFX-r2-Bs-phe-M_at',
#        'target', 'VITAL_STATUS', 'MTHS_TO_LAST_CLINICAL_ASSESSMENT',
#        'MONTHS_TO_LAST_CONTACT_OR_DEATH', 'PATHOLOGIC_N_STAGE',
#        'PATHOLOGIC_T_STAGE', 'MEDIAN_INTENSITY_UNNORMALIZED'],
#       dtype='object', length=1500)

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import  mutual_info_regression
## Selecting the top 20 percentile
selected_top_columns = SelectPercentile(mutual_info_regression, percentile=20)
selected_top_columns.fit(X_train.fillna(0), y_train)
# Out:
# SelectPercentile(percentile=20,
#                  score_func=<function mutual_info_regression at 0x7f21bf5147a0>)

# %%
selected_top_columns.get_support()
# Out:
# array([False, False, False, ..., False, False,  True])

# %%
pd.options.display.max_rows = None
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['1405_i_at', '200011_s_at', '200033_at', '200034_s_at', '200037_s_at',
#        '200045_at', '200047_s_at', '200050_at', '200051_at', '200061_s_at',
#        ...
#        'ADJUVANT_CHEMO', 'ADJUVANT_RT', 'VITAL_STATUS',
#        'FIRST_PROGRESSION_OR_RELAPSE', 'MTHS_TO_LAST_CLINICAL_ASSESSMENT',
#        'MONTHS_TO_LAST_CONTACT_OR_DEATH', 'SMOKING_HISTORY',
#        'PATHOLOGIC_T_STAGE', 'PCT_SINGLE_OUTLIER', 'Histologic grade'],
#       dtype='object', length=4462)
